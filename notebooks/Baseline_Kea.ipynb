# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../data/df_prepped.csv')
df.head()
# Out:
#    Year Countries  Sand_1  Sand_2  Sand_3  Sand_4  Sand_5  Sand_6  Sand_7  \
# 0  2007    Angola      50      51      51      48      45      46      46
# 1  2007    Angola      62      64      63      59      58      59      59
# 2  2007    Angola      69      71      70      67      65      65      66
# 3  2007    Angola      60      63      61      57      53      53      53
# 4  2007    Angola      67      69      68      63      61      61      61
#
#    Clay_1  ...  spi_12mon_10  spi_12mon_11  spi_12mon_12  Y_maize_major  \
# 0      37  ...      0.994139      1.051325      0.891661       0.615357
# 1      27  ...      0.269691     -0.364644     -0.698008       0.257656
# 2      19  ...     -0.574688     -1.053915     -1.099187       4.286831
# 3      29  ...      0.433416      0.436678      0.300900       0.700384
# 4      22  ...      1.139544      0.957729      0.125110       0.553450
#
#          Farm  Sow_Maize_month_int  Harvest_Maize_month_int  maize_lag-1  \
# 0  104_Angola                    9                        4     0.554392
# 1   99_Angola                    9                        4     0.117051
# 2  108_Angola                    9                        4     3.093239
# 3  102_Angola                    9                        4     0.677797
# 4   43_Angola                    9                        4     0.412071
#
#    maize_lag-2  maize_lag-3
# 0     0.721607     0.620005
# 1     0.300217     0.212699
# 2     4.044452     2.295351
# 3     0.907431     0.783018
# 4     0.675967     0.605584
#
# [5 rows x 85 columns]

# %%
df.Countries.nunique()
# Out:
# 30

# %%
df.Farm.nunique()
# Out:
# 3887

# %% [markdown]
# One-hot for categorical variables

# %%
df_onehot = pd.get_dummies(df, columns=['Countries', 'Farm'], prefix=['Country', 'Farm'])
df_onehot
# Out:
#        Year  Sand_1  Sand_2  Sand_3  Sand_4  Sand_5  Sand_6  Sand_7  Clay_1  \
# 0      2007      50      51      51      48      45      46      46      37
# 1      2007      62      64      63      59      58      59      59      27
# 2      2007      69      71      70      67      65      65      66      19
# 3      2007      60      63      61      57      53      53      53      29
# 4      2007      67      69      68      63      61      61      61      22
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 32354  2016      73      75      74      69      66      66      66      20
# 32355  2016      57      58      58      54      52      51      52      28
# 32356  2016      55      57      56      54      52      51      51      30
# 32357  2016      70      72      71      67      63      63      62      17
# 32358  2016      62      64      63      60      59      60      60      24
#
#        Clay_2  ...  Farm_992_Democratic Republic of the Congo  \
# 0          35  ...                                      False
# 1          25  ...                                      False
# 2          16  ...                                      False
# 3          26  ...                                      False
# 4          19  ...                                      False
# ...       ...  ...                                        ...
# 32354      18  ...                                      False
# 32355      26  ...                                      False
# 32356      28  ...                                      False
# 32357      14  ...                                      False
# 32358      22  ...                                      False
#
#        Farm_993_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_994_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_995_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_996_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_997_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_998_Democratic Republic of the Congo  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 32354                                      False
# 32355                                      False
# 32356                                      False
# 32357                                      False
# 32358                                      False
#
#        Farm_999_Democratic Republic of the Congo  Farm_99_Angola  \
# 0                                          False           False
# 1                                          False            True
# 2                                          False           False
# 3                                          False           False
# 4                                          False           False
# ...                                          ...             ...
# 32354                                      False           False
# 32355                                      False           False
# 32356                                      False           False
# 32357                                      False           False
# 32358                                      False           False
#
#        Farm_9_Angola
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 32354          False
# 32355          False
# 32356          False
# 32357          False
# 32358          False
#
# [32359 rows x 4000 columns]

# %%
list(df_onehot.columns)
# Out:
# ['Year',
#  'Sand_1',
#  'Sand_2',
#  'Sand_3',
#  'Sand_4',
#  'Sand_5',
#  'Sand_6',
#  'Sand_7',
#  'Clay_1',
#  'Clay_2',
#  'Clay_3',
#  'Clay_4',
#  'Clay_5',
#  'Clay_6',
#  'Clay_7',
#  'OC_1',
#  'OC_2',
#  'OC_3',
#  'OC_4',
#  'OC_5',
#  'OC_6',
#  'OC_7',
#  'PAW_1',
#  'PAW_2',
#  'PAW_3',
#  'PAW_4',
#  'PAW_5',
#  'PAW_6',
#  'PAW_7',
#  'pcp_1',
#  'pcp_2',
#  'pcp_3',
#  'pcp_4',
#  'pcp_5',
#  'pcp_6',
#  'pcp_7',
#  'pcp_8',
#  'pcp_9',
#  'pcp_10',
#  'pcp_11',
#  'pcp_12',
#  'tmax_1',
#  'tmax_2',
#  'tmax_3',
#  'tmax_4',
#  'tmax_5',
#  'tmax_6',
#  'tmax_7',
#  'tmax_8',
#  'tmax_9',
#  'tmax_10',
#  'tmax_11',
#  'tmax_12',
#  'tmin_1',
#  'tmin_2',
#  'tmin_3',
#  'tmin_4',
#  'tmin_5',
#  'tmin_6',
#  'tmin_7',
#  'tmin_8',
#  'tmin_9',
#  'tmin_10',
#  'tmin_11',
#  'tmin_12',
#  'spi_12mon_1',
#  'spi_12mon_2',
#  'spi_12mon_3',
#  'spi_12mon_4',
#  'spi_12mon_5',
#  'spi_12mon_6',
#  'spi_12mon_7',
#  'spi_12mon_8',
#  'spi_12mon_9',
#  'spi_12mon_10',
#  'spi_12mon_11',
#  'spi_12mon_12',
#  'Y_maize_major',
#  'Sow_Maize_month_int',
#  'Harvest_Maize_month_int',
#  'maize_lag-1',
#  'maize_lag-2',
#  'maize_lag-3',
#  'Country_Angola',
#  'Country_Benin',
#  'Country_Botswana',
#  'Country_Burkina Faso',
#  'Country_Burundi',
#  'Country_Cameroon',
#  'Country_Central African Republic',
#  'Country_Chad',
#  'Country_Congo',
#  'Country_Democratic Republic of the Congo',
#  'Country_Egypt',
#  'Country_Eritrea',
#  'Country_Ethiopia',
#  'Country_Gabon',
#  'Country_Ghana',
#  'Country_Kenya',
#  'Country_Madagascar',
#  'Country_Malawi',
#  'Country_Mozambique',
#  'Country_Namibia',
#  'Country_Niger',
#  'Country_Nigeria',
#  'Country_Somalia',
#  'Country_South Africa',
#  'Country_South Sudan',
#  'Country_Togo',
#  'Country_Uganda',
#  'Country_United Republic of Tanzania',
#  'Country_Zambia',
#  'Country_Zimbabwe',
#  'Farm_0_Angola',
#  'Farm_1000_Democratic Republic of the Congo',
#  'Farm_1001_Democratic Republic of the Congo',
#  'Farm_1002_Democratic Republic of the Congo',
#  'Farm_1003_Democratic Republic of the Congo',
#  'Farm_1004_Democratic Republic of the Congo',
#  'Farm_1005_Democratic Republic of the Congo',
#  'Farm_1006_Democratic Republic of the Congo',
#  'Farm_1007_Democratic Republic of the Congo',
#  'Farm_1008_Democratic Republic of the Congo',
#  'Farm_1009_Democratic Republic of the Congo',
#  'Farm_100_Angola',
#  'Farm_1010_Democratic Republic of the Congo',
#  'Farm_1011_Democratic Republic of the Congo',
#  'Farm_1012_Democratic Republic of the Congo',
#  'Farm_1013_Democratic Republic of the Congo',
#  'Farm_1014_Democratic Republic of the Congo',
#  'Farm_1015_Democratic Republic of the Congo',
#  'Farm_1016_Democratic Republic of the Congo',
#  'Farm_1017_Democratic Republic of the Congo',
#  'Farm_1018_Democratic Republic of the Congo',
#  'Farm_1019_Democratic Republic of the Congo',
#  'Farm_101_Angola',
#  'Farm_1020_Democratic Republic of the Congo',
#  'Farm_1021_Democratic Republic of the Congo',
#  'Farm_1022_Democratic Republic of the Congo',
#  'Farm_1023_Democratic Republic of the Congo',
#  'Farm_1024_Democratic Republic of the Congo',
#  'Farm_1025_Democratic Republic of the Congo',
#  'Farm_1026_Democratic Republic of the Congo',
#  'Farm_1027_Democratic Republic of the Congo',
#  'Farm_1028_Democratic Republic of the Congo',
#  'Farm_1029_Democratic Republic of the Congo',
#  'Farm_102_Angola',
#  'Farm_1030_Democratic Republic of the Congo',
#  'Farm_1031_Democratic Republic of the Congo',
#  'Farm_1032_Democratic Republic of the Congo',
#  'Farm_1033_Democratic Republic of the Congo',
#  'Farm_1034_Democratic Republic of the Congo',
#  'Farm_1035_Democratic Republic of the Congo',
#  'Farm_1036_Democratic Republic of the Congo',
#  'Farm_1037_Democratic Republic of the Congo',
#  'Farm_1038_Democratic Republic of the Congo',
#  'Farm_1039_Democratic Republic of the Congo',
#  'Farm_103_Angola',
#  'Farm_1040_Democratic Republic of the Congo',
#  'Farm_1041_Democratic Republic of the Congo',
#  'Farm_1042_Democratic Republic of the Congo',
#  'Farm_1043_Democratic Republic of the Congo',
#  'Farm_1044_Democratic Republic of the Congo',
#  'Farm_1045_Democratic Republic of the Congo',
#  'Farm_1046_Democratic Republic of the Congo',
#  'Farm_1047_Democratic Republic of the Congo',
#  'Farm_1048_Democratic Republic of the Congo',
#  'Farm_1049_Democratic Republic of the Congo',
#  'Farm_104_Angola',
#  'Farm_1050_Democratic Republic of the Congo',
#  'Farm_1051_Democratic Republic of the Congo',
#  'Farm_1052_Democratic Republic of the Congo',
#  'Farm_1053_Democratic Republic of the Congo',
#  'Farm_1054_Democratic Republic of the Congo',
#  'Farm_1055_Democratic Republic of the Congo',
#  'Farm_1056_Democratic Republic of the Congo',
#  'Farm_1057_Democratic Republic of the Congo',
#  'Farm_1058_Democratic Republic of the Congo',
#  'Farm_1059_Democratic Republic of the Congo',
#  'Farm_105_Angola',
#  'Farm_1060_Democratic Republic of the Congo',
#  'Farm_1061_Democratic Republic of the Congo',
#  'Farm_1062_Democratic Republic of the Congo',
#  'Farm_1063_Democratic Republic of the Congo',
#  'Farm_1064_Democratic Republic of the Congo',
#  'Farm_1065_Democratic Republic of the Congo',
#  'Farm_1066_Democratic Republic of the Congo',
#  'Farm_1067_Democratic Republic of the Congo',
#  'Farm_1068_Democratic Republic of the Congo',
#  'Farm_1069_Democratic Republic of the Congo',
#  'Farm_106_Angola',
#  'Farm_1070_Democratic Republic of the Congo',
#  'Farm_1071_Democratic Republic of the Congo',
#  'Farm_1072_Democratic Republic of the Congo',
#  'Farm_1073_Democratic Republic of the Congo',
#  'Farm_1074_Democratic Republic of the Congo',
#  'Farm_1075_Democratic Republic of the Congo',
#  'Farm_1076_Democratic Republic of the Congo',
#  'Farm_1077_Democratic Republic of the Congo',
#  'Farm_1078_Democratic Republic of the Congo',
#  'Farm_1079_Democratic Republic of the Congo',
#  'Farm_107_Angola',
#  'Farm_1080_Democratic Republic of the Congo',
#  'Farm_1081_Democratic Republic of the Congo',
#  'Farm_1082_Democratic Republic of the Congo',
#  'Farm_1083_Democratic Republic of the Congo',
#  'Farm_1084_Democratic Republic of the Congo',
#  'Farm_1085_Democratic Republic of the Congo',
#  'Farm_1086_Democratic Republic of the Congo',
#  'Farm_1087_Democratic Republic of the Congo',
#  'Farm_1088_Democratic Republic of the Congo',
#  'Farm_1089_Democratic Republic of the Congo',
#  'Farm_108_Angola',
#  'Farm_1090_Democratic Republic of the Congo',
#  'Farm_1091_Democratic Republic of the Congo',
#  'Farm_1092_Democratic Republic of the Congo',
#  'Farm_1093_Democratic Republic of the Congo',
#  'Farm_1094_Democratic Republic of the Congo',
#  'Farm_1095_Democratic Republic of the Congo',
#  'Farm_1096_Democratic Republic of the Congo',
#  'Farm_1097_Democratic Republic of the Congo',
#  'Farm_1098_Democratic Republic of the Congo',
#  'Farm_1099_Democratic Republic of the Congo',
#  'Farm_109_Angola',
#  'Farm_10_Angola',
#  'Farm_1100_Democratic Republic of the Congo',
#  'Farm_1101_Democratic Republic of the Congo',
#  'Farm_1102_Democratic Republic of the Congo',
#  'Farm_1103_Democratic Republic of the Congo',
#  'Farm_1104_Democratic Republic of the Congo',
#  'Farm_1105_Democratic Republic of the Congo',
#  'Farm_1106_Democratic Republic of the Congo',
#  'Farm_1107_Democratic Republic of the Congo',
#  'Farm_1108_Democratic Republic of the Congo',
#  'Farm_1109_Democratic Republic of the Congo',
#  'Farm_110_Angola',
#  'Farm_1110_Democratic Republic of the Congo',
#  'Farm_1111_Democratic Republic of the Congo',
#  'Farm_1112_Democratic Republic of the Congo',
#  'Farm_1113_Democratic Republic of the Congo',
#  'Farm_1114_Democratic Republic of the Congo',
#  'Farm_1115_Democratic Republic of the Congo',
#  'Farm_1116_Democratic Republic of the Congo',
#  'Farm_1117_Democratic Republic of the Congo',
#  'Farm_1118_Democratic Republic of the Congo',
#  'Farm_1119_Democratic Republic of the Congo',
#  'Farm_111_Angola',
#  'Farm_1120_Democratic Republic of the Congo',
#  'Farm_1121_Democratic Republic of the Congo',
#  'Farm_1122_Democratic Republic of the Congo',
#  'Farm_1123_Democratic Republic of the Congo',
#  'Farm_1124_Democratic Republic of the Congo',
#  'Farm_1125_Democratic Republic of the Congo',
#  'Farm_1126_Democratic Republic of the Congo',
#  'Farm_1127_Democratic Republic of the Congo',
#  'Farm_1128_Democratic Republic of the Congo',
#  'Farm_1129_Democratic Republic of the Congo',
#  'Farm_112_Angola',
#  'Farm_1130_Democratic Republic of the Congo',
#  'Farm_1131_Democratic Republic of the Congo',
#  'Farm_1132_Democratic Republic of the Congo',
#  'Farm_1133_Democratic Republic of the Congo',
#  'Farm_1134_Democratic Republic of the Congo',
#  'Farm_1135_Democratic Republic of the Congo',
#  'Farm_1136_Democratic Republic of the Congo',
#  'Farm_1137_Democratic Republic of the Congo',
#  'Farm_1138_Democratic Republic of the Congo',
#  'Farm_1139_Democratic Republic of the Congo',
#  'Farm_113_Angola',
#  'Farm_1140_Democratic Republic of the Congo',
#  'Farm_1141_Democratic Republic of the Congo',
#  'Farm_1142_Democratic Republic of the Congo',
#  'Farm_1143_Democratic Republic of the Congo',
#  'Farm_1144_Democratic Republic of the Congo',
#  'Farm_1145_Democratic Republic of the Congo',
#  'Farm_1146_Democratic Republic of the Congo',
#  'Farm_1147_Democratic Republic of the Congo',
#  'Farm_1148_Democratic Republic of the Congo',
#  'Farm_1149_Democratic Republic of the Congo',
#  'Farm_114_Angola',
#  'Farm_1150_Democratic Republic of the Congo',
#  'Farm_1151_Democratic Republic of the Congo',
#  'Farm_1152_Democratic Republic of the Congo',
#  'Farm_1153_Democratic Republic of the Congo',
#  'Farm_1154_Democratic Republic of the Congo',
#  'Farm_1155_Democratic Republic of the Congo',
#  'Farm_1156_Democratic Republic of the Congo',
#  'Farm_1157_Democratic Republic of the Congo',
#  'Farm_1158_Democratic Republic of the Congo',
#  'Farm_1159_Democratic Republic of the Congo',
#  'Farm_115_Angola',
#  'Farm_1160_Democratic Republic of the Congo',
#  'Farm_1161_Democratic Republic of the Congo',
#  'Farm_1162_Democratic Republic of the Congo',
#  'Farm_1163_Democratic Republic of the Congo',
#  'Farm_1164_Democratic Republic of the Congo',
#  'Farm_1165_Democratic Republic of the Congo',
#  'Farm_1166_Democratic Republic of the Congo',
#  'Farm_1167_Democratic Republic of the Congo',
#  'Farm_1168_Democratic Republic of the Congo',
#  'Farm_1169_Democratic Republic of the Congo',
#  'Farm_116_Angola',
#  'Farm_1170_Democratic Republic of the Congo',
#  'Farm_1171_Democratic Republic of the Congo',
#  'Farm_1172_Democratic Republic of the Congo',
#  'Farm_1173_Democratic Republic of the Congo',
#  'Farm_1174_Democratic Republic of the Congo',
#  'Farm_1175_Democratic Republic of the Congo',
#  'Farm_1176_Democratic Republic of the Congo',
#  'Farm_1177_Democratic Republic of the Congo',
#  'Farm_1178_Democratic Republic of the Congo',
#  'Farm_1179_Democratic Republic of the Congo',
#  'Farm_117_Angola',
#  'Farm_1180_Democratic Republic of the Congo',
#  'Farm_1181_Democratic Republic of the Congo',
#  'Farm_1182_Democratic Republic of the Congo',
#  'Farm_1183_Democratic Republic of the Congo',
#  'Farm_1184_Democratic Republic of the Congo',
#  'Farm_1185_Democratic Republic of the Congo',
#  'Farm_1186_Democratic Republic of the Congo',
#  'Farm_1187_Democratic Republic of the Congo',
#  'Farm_1188_Democratic Republic of the Congo',
#  'Farm_1189_Democratic Republic of the Congo',
#  'Farm_118_Angola',
#  'Farm_1190_Democratic Republic of the Congo',
#  'Farm_1191_Democratic Republic of the Congo',
#  'Farm_1192_Democratic Republic of the Congo',
#  'Farm_1193_Democratic Republic of the Congo',
#  'Farm_1194_Democratic Republic of the Congo',
#  'Farm_1195_Democratic Republic of the Congo',
#  'Farm_1196_Democratic Republic of the Congo',
#  'Farm_1197_Democratic Republic of the Congo',
#  'Farm_1198_Democratic Republic of the Congo',
#  'Farm_1199_Democratic Republic of the Congo',
#  'Farm_119_Angola',
#  'Farm_11_Angola',
#  'Farm_1200_Democratic Republic of the Congo',
#  'Farm_1201_Democratic Republic of the Congo',
#  'Farm_1202_Democratic Republic of the Congo',
#  'Farm_1203_Democratic Republic of the Congo',
#  'Farm_1204_Democratic Republic of the Congo',
#  'Farm_1205_Democratic Republic of the Congo',
#  'Farm_1206_Democratic Republic of the Congo',
#  'Farm_1207_Democratic Republic of the Congo',
#  'Farm_1208_Democratic Republic of the Congo',
#  'Farm_1209_Democratic Republic of the Congo',
#  'Farm_120_Angola',
#  'Farm_1210_Democratic Republic of the Congo',
#  'Farm_1211_Democratic Republic of the Congo',
#  'Farm_1212_Democratic Republic of the Congo',
#  'Farm_1213_Democratic Republic of the Congo',
#  'Farm_1214_Democratic Republic of the Congo',
#  'Farm_1215_Democratic Republic of the Congo',
#  'Farm_1216_Democratic Republic of the Congo',
#  'Farm_1217_Democratic Republic of the Congo',
#  'Farm_1218_Democratic Republic of the Congo',
#  'Farm_1219_Democratic Republic of the Congo',
#  'Farm_121_Angola',
#  'Farm_1220_Democratic Republic of the Congo',
#  'Farm_1221_Democratic Republic of the Congo',
#  'Farm_1222_Democratic Republic of the Congo',
#  'Farm_1223_Democratic Republic of the Congo',
#  'Farm_1224_Democratic Republic of the Congo',
#  'Farm_1225_Democratic Republic of the Congo',
#  'Farm_1226_Democratic Republic of the Congo',
#  'Farm_1227_Democratic Republic of the Congo',
#  'Farm_1228_Democratic Republic of the Congo',
#  'Farm_1229_Democratic Republic of the Congo',
#  'Farm_122_Angola',
#  'Farm_1230_Democratic Republic of the Congo',
#  'Farm_1231_Democratic Republic of the Congo',
#  'Farm_1232_Democratic Republic of the Congo',
#  'Farm_1233_Democratic Republic of the Congo',
#  'Farm_1234_Democratic Republic of the Congo',
#  'Farm_1235_Democratic Republic of the Congo',
#  'Farm_1236_Democratic Republic of the Congo',
#  'Farm_1237_Democratic Republic of the Congo',
#  'Farm_1238_Democratic Republic of the Congo',
#  'Farm_1239_Democratic Republic of the Congo',
#  'Farm_123_Angola',
#  'Farm_1240_Democratic Republic of the Congo',
#  'Farm_1241_Democratic Republic of the Congo',
#  'Farm_1242_Democratic Republic of the Congo',
#  'Farm_1243_Democratic Republic of the Congo',
#  'Farm_1244_Democratic Republic of the Congo',
#  'Farm_1245_Democratic Republic of the Congo',
#  'Farm_1246_Democratic Republic of the Congo',
#  'Farm_1247_Democratic Republic of the Congo',
#  'Farm_1248_Democratic Republic of the Congo',
#  'Farm_1249_Democratic Republic of the Congo',
#  'Farm_124_Angola',
#  'Farm_1250_Democratic Republic of the Congo',
#  'Farm_1251_Democratic Republic of the Congo',
#  'Farm_1252_Democratic Republic of the Congo',
#  'Farm_1253_Democratic Republic of the Congo',
#  'Farm_1254_Democratic Republic of the Congo',
#  'Farm_1255_Democratic Republic of the Congo',
#  'Farm_1256_Democratic Republic of the Congo',
#  'Farm_1257_Democratic Republic of the Congo',
#  'Farm_1258_Democratic Republic of the Congo',
#  'Farm_1259_Democratic Republic of the Congo',
#  'Farm_125_Angola',
#  'Farm_1260_Democratic Republic of the Congo',
#  'Farm_1261_Democratic Republic of the Congo',
#  'Farm_1262_Democratic Republic of the Congo',
#  'Farm_1263_Democratic Republic of the Congo',
#  'Farm_1264_Democratic Republic of the Congo',
#  'Farm_1265_Democratic Republic of the Congo',
#  'Farm_1266_Democratic Republic of the Congo',
#  'Farm_1267_Democratic Republic of the Congo',
#  'Farm_1268_Democratic Republic of the Congo',
#  'Farm_1269_Democratic Republic of the Congo',
#  'Farm_126_Angola',
#  'Farm_1270_Democratic Republic of the Congo',
#  'Farm_1271_Democratic Republic of the Congo',
#  'Farm_1272_Democratic Republic of the Congo',
#  'Farm_1273_Democratic Republic of the Congo',
#  'Farm_1274_Democratic Republic of the Congo',
#  'Farm_1275_Democratic Republic of the Congo',
#  'Farm_1276_Democratic Republic of the Congo',
#  'Farm_1277_Democratic Republic of the Congo',
#  'Farm_1278_Democratic Republic of the Congo',
#  'Farm_1279_Democratic Republic of the Congo',
#  'Farm_127_Angola',
#  'Farm_1280_Democratic Republic of the Congo',
#  'Farm_1281_Democratic Republic of the Congo',
#  'Farm_1282_Democratic Republic of the Congo',
#  'Farm_1283_Democratic Republic of the Congo',
#  'Farm_1284_Democratic Republic of the Congo',
#  'Farm_1285_Democratic Republic of the Congo',
#  'Farm_1286_Democratic Republic of the Congo',
#  'Farm_1287_Democratic Republic of the Congo',
#  'Farm_1288_Democratic Republic of the Congo',
#  'Farm_1289_Democratic Republic of the Congo',
#  'Farm_128_Angola',
#  'Farm_1290_Democratic Republic of the Congo',
#  'Farm_1291_Democratic Republic of the Congo',
#  'Farm_1292_Democratic Republic of the Congo',
#  'Farm_1293_Democratic Republic of the Congo',
#  'Farm_1294_Democratic Republic of the Congo',
#  'Farm_1295_Democratic Republic of the Congo',
#  'Farm_1296_Democratic Republic of the Congo',
#  'Farm_1297_Democratic Republic of the Congo',
#  'Farm_1298_Democratic Republic of the Congo',
#  'Farm_1299_Democratic Republic of the Congo',
#  'Farm_129_Angola',
#  'Farm_12_Angola',
#  'Farm_1300_Democratic Republic of the Congo',
#  'Farm_1301_Democratic Republic of the Congo',
#  'Farm_1302_Democratic Republic of the Congo',
#  'Farm_1303_Democratic Republic of the Congo',
#  'Farm_1304_Democratic Republic of the Congo',
#  'Farm_1305_Democratic Republic of the Congo',
#  'Farm_1306_Democratic Republic of the Congo',
#  'Farm_1307_Democratic Republic of the Congo',
#  'Farm_1308_Democratic Republic of the Congo',
#  'Farm_1309_Democratic Republic of the Congo',
#  'Farm_130_Angola',
#  'Farm_1310_Democratic Republic of the Congo',
#  'Farm_1311_Democratic Republic of the Congo',
#  'Farm_1312_Democratic Republic of the Congo',
#  'Farm_1313_Democratic Republic of the Congo',
#  'Farm_1314_Democratic Republic of the Congo',
#  'Farm_1315_Democratic Republic of the Congo',
#  'Farm_1316_Democratic Republic of the Congo',
#  'Farm_1317_Democratic Republic of the Congo',
#  'Farm_1318_Democratic Republic of the Congo',
#  'Farm_1319_Democratic Republic of the Congo',
#  'Farm_131_Angola',
#  'Farm_1320_Democratic Republic of the Congo',
#  'Farm_1321_Democratic Republic of the Congo',
#  'Farm_1322_Democratic Republic of the Congo',
#  'Farm_1323_Democratic Republic of the Congo',
#  'Farm_1324_Democratic Republic of the Congo',
#  'Farm_1325_Democratic Republic of the Congo',
#  'Farm_1326_Democratic Republic of the Congo',
#  'Farm_1327_Democratic Republic of the Congo',
#  'Farm_1328_Democratic Republic of the Congo',
#  'Farm_1329_Democratic Republic of the Congo',
#  'Farm_132_Angola',
#  'Farm_1330_Democratic Republic of the Congo',
#  'Farm_1331_Democratic Republic of the Congo',
#  'Farm_1332_Democratic Republic of the Congo',
#  'Farm_1333_Democratic Republic of the Congo',
#  'Farm_1334_Democratic Republic of the Congo',
#  'Farm_1335_Democratic Republic of the Congo',
#  'Farm_1336_Democratic Republic of the Congo',
#  'Farm_1337_Democratic Republic of the Congo',
#  'Farm_1338_Democratic Republic of the Congo',
#  'Farm_1339_Democratic Republic of the Congo',
#  'Farm_133_Angola',
#  'Farm_1340_Democratic Republic of the Congo',
#  'Farm_1341_Democratic Republic of the Congo',
#  'Farm_1342_Democratic Republic of the Congo',
#  'Farm_1343_Democratic Republic of the Congo',
#  'Farm_1344_Democratic Republic of the Congo',
#  'Farm_1345_Democratic Republic of the Congo',
#  'Farm_1346_Democratic Republic of the Congo',
#  'Farm_1347_Democratic Republic of the Congo',
#  'Farm_1348_Democratic Republic of the Congo',
#  'Farm_1349_Democratic Republic of the Congo',
#  'Farm_134_Angola',
#  'Farm_1350_Democratic Republic of the Congo',
#  'Farm_1351_Democratic Republic of the Congo',
#  'Farm_1352_Democratic Republic of the Congo',
#  'Farm_1353_Democratic Republic of the Congo',
#  'Farm_1354_Democratic Republic of the Congo',
#  'Farm_1355_Democratic Republic of the Congo',
#  'Farm_1356_Democratic Republic of the Congo',
#  'Farm_1357_Democratic Republic of the Congo',
#  'Farm_1358_Democratic Republic of the Congo',
#  'Farm_1359_Democratic Republic of the Congo',
#  'Farm_135_Angola',
#  'Farm_1360_Democratic Republic of the Congo',
#  'Farm_1361_Democratic Republic of the Congo',
#  'Farm_1362_Democratic Republic of the Congo',
#  'Farm_1363_Democratic Republic of the Congo',
#  'Farm_1364_Democratic Republic of the Congo',
#  'Farm_1365_Democratic Republic of the Congo',
#  'Farm_1366_Democratic Republic of the Congo',
#  'Farm_1367_Democratic Republic of the Congo',
#  'Farm_1368_Democratic Republic of the Congo',
#  'Farm_1369_Democratic Republic of the Congo',
#  'Farm_136_Angola',
#  'Farm_1370_Democratic Republic of the Congo',
#  'Farm_1371_Democratic Republic of the Congo',
#  'Farm_1372_Democratic Republic of the Congo',
#  'Farm_1373_Democratic Republic of the Congo',
#  'Farm_1374_Democratic Republic of the Congo',
#  'Farm_1375_Democratic Republic of the Congo',
#  'Farm_1376_Democratic Republic of the Congo',
#  'Farm_1377_Democratic Republic of the Congo',
#  'Farm_1378_Democratic Republic of the Congo',
#  'Farm_1379_Democratic Republic of the Congo',
#  'Farm_137_Angola',
#  'Farm_1380_Democratic Republic of the Congo',
#  'Farm_1381_Democratic Republic of the Congo',
#  'Farm_1382_Democratic Republic of the Congo',
#  'Farm_1383_Democratic Republic of the Congo',
#  'Farm_1384_Democratic Republic of the Congo',
#  'Farm_1385_Democratic Republic of the Congo',
#  'Farm_1386_Democratic Republic of the Congo',
#  'Farm_1387_Democratic Republic of the Congo',
#  'Farm_1388_Democratic Republic of the Congo',
#  'Farm_1389_Democratic Republic of the Congo',
#  'Farm_138_Angola',
#  'Farm_1390_Democratic Republic of the Congo',
#  'Farm_1391_Democratic Republic of the Congo',
#  'Farm_1392_Democratic Republic of the Congo',
#  'Farm_1393_Democratic Republic of the Congo',
#  'Farm_1394_Democratic Republic of the Congo',
#  'Farm_1395_Democratic Republic of the Congo',
#  'Farm_1396_Democratic Republic of the Congo',
#  'Farm_1397_Democratic Republic of the Congo',
#  'Farm_1398_Democratic Republic of the Congo',
#  'Farm_1399_Democratic Republic of the Congo',
#  'Farm_139_Angola',
#  'Farm_13_Angola',
#  'Farm_1400_Democratic Republic of the Congo',
#  'Farm_1401_Democratic Republic of the Congo',
#  'Farm_1402_Democratic Republic of the Congo',
#  'Farm_1403_Democratic Republic of the Congo',
#  'Farm_1404_Democratic Republic of the Congo',
#  'Farm_1405_Democratic Republic of the Congo',
#  'Farm_1406_Democratic Republic of the Congo',
#  'Farm_1407_Democratic Republic of the Congo',
#  'Farm_1408_Democratic Republic of the Congo',
#  'Farm_1409_Democratic Republic of the Congo',
#  'Farm_140_Angola',
#  'Farm_1410_Democratic Republic of the Congo',
#  'Farm_1411_Democratic Republic of the Congo',
#  'Farm_1412_Democratic Republic of the Congo',
#  'Farm_1413_Democratic Republic of the Congo',
#  'Farm_1414_Democratic Republic of the Congo',
#  'Farm_1415_Democratic Republic of the Congo',
#  'Farm_1416_Democratic Republic of the Congo',
#  'Farm_1417_Democratic Republic of the Congo',
#  'Farm_1418_Democratic Republic of the Congo',
#  'Farm_1419_Democratic Republic of the Congo',
#  'Farm_141_Angola',
#  'Farm_1420_Democratic Republic of the Congo',
#  'Farm_1421_Democratic Republic of the Congo',
#  'Farm_1422_Democratic Republic of the Congo',
#  'Farm_1423_Democratic Republic of the Congo',
#  'Farm_1424_Democratic Republic of the Congo',
#  'Farm_1425_Democratic Republic of the Congo',
#  'Farm_1426_Democratic Republic of the Congo',
#  'Farm_1427_Democratic Republic of the Congo',
#  'Farm_1428_Democratic Republic of the Congo',
#  'Farm_1429_Democratic Republic of the Congo',
#  'Farm_142_Angola',
#  'Farm_1430_Democratic Republic of the Congo',
#  'Farm_1431_Democratic Republic of the Congo',
#  'Farm_1432_Democratic Republic of the Congo',
#  'Farm_1433_Democratic Republic of the Congo',
#  'Farm_1434_Democratic Republic of the Congo',
#  'Farm_1435_Democratic Republic of the Congo',
#  'Farm_1436_Democratic Republic of the Congo',
#  'Farm_1437_Democratic Republic of the Congo',
#  'Farm_1438_Democratic Republic of the Congo',
#  'Farm_1439_Democratic Republic of the Congo',
#  'Farm_143_Angola',
#  'Farm_1440_Democratic Republic of the Congo',
#  'Farm_1441_Democratic Republic of the Congo',
#  'Farm_1442_Democratic Republic of the Congo',
#  'Farm_1443_Democratic Republic of the Congo',
#  'Farm_1444_Democratic Republic of the Congo',
#  'Farm_1445_Democratic Republic of the Congo',
#  'Farm_1446_Democratic Republic of the Congo',
#  'Farm_1447_Democratic Republic of the Congo',
#  'Farm_1448_Democratic Republic of the Congo',
#  'Farm_1449_Egypt',
#  'Farm_144_Angola',
#  'Farm_1450_Egypt',
#  'Farm_1451_Egypt',
#  'Farm_1452_Egypt',
#  'Farm_1453_Egypt',
#  'Farm_1454_Egypt',
#  'Farm_1455_Egypt',
#  'Farm_1456_Egypt',
#  'Farm_1457_Egypt',
#  'Farm_1458_Egypt',
#  'Farm_1459_Egypt',
#  'Farm_145_Angola',
#  'Farm_1460_Egypt',
#  'Farm_1461_Egypt',
#  'Farm_1462_Egypt',
#  'Farm_1463_Egypt',
#  'Farm_1464_Egypt',
#  'Farm_1465_Eritrea',
#  'Farm_1466_Eritrea',
#  'Farm_1467_Eritrea',
#  'Farm_1468_Eritrea',
#  'Farm_1469_Eritrea',
#  'Farm_146_Angola',
#  'Farm_1470_Eritrea',
#  'Farm_1471_Eritrea',
#  'Farm_1472_Eritrea',
#  'Farm_1473_Eritrea',
#  'Farm_1474_Eritrea',
#  'Farm_1475_Eritrea',
#  'Farm_1476_Eritrea',
#  'Farm_1477_Eritrea',
#  'Farm_1478_Eritrea',
#  'Farm_1479_Eritrea',
#  'Farm_147_Angola',
#  'Farm_1480_Eritrea',
#  'Farm_1481_Eritrea',
#  'Farm_1482_Eritrea',
#  'Farm_1483_Eritrea',
#  'Farm_1484_Eritrea',
#  'Farm_1485_Eritrea',
#  'Farm_1486_Eritrea',
#  'Farm_1487_Eritrea',
#  'Farm_1488_Ethiopia',
#  'Farm_1489_Ethiopia',
#  'Farm_148_Angola',
#  'Farm_1490_Ethiopia',
#  'Farm_1491_Ethiopia',
#  'Farm_1492_Ethiopia',
#  'Farm_1493_Ethiopia',
#  'Farm_1494_Ethiopia',
#  'Farm_1495_Ethiopia',
#  'Farm_1496_Ethiopia',
#  'Farm_1497_Ethiopia',
#  'Farm_1498_Ethiopia',
#  'Farm_1499_Ethiopia',
#  'Farm_149_Angola',
#  'Farm_14_Angola',
#  'Farm_1500_Ethiopia',
#  'Farm_1501_Ethiopia',
#  'Farm_1502_Ethiopia',
#  'Farm_1503_Ethiopia',
#  'Farm_1504_Ethiopia',
#  'Farm_1505_Ethiopia',
#  'Farm_1506_Ethiopia',
#  'Farm_1507_Ethiopia',
#  'Farm_1508_Ethiopia',
#  'Farm_1509_Ethiopia',
#  'Farm_150_Angola',
#  'Farm_1510_Ethiopia',
#  'Farm_1511_Ethiopia',
#  'Farm_1512_Ethiopia',
#  'Farm_1513_Ethiopia',
#  'Farm_1514_Ethiopia',
#  'Farm_1515_Ethiopia',
#  'Farm_1516_Ethiopia',
#  'Farm_1517_Ethiopia',
#  'Farm_1518_Ethiopia',
#  'Farm_1519_Ethiopia',
#  'Farm_151_Angola',
#  'Farm_1520_Ethiopia',
#  'Farm_1521_Ethiopia',
#  'Farm_1522_Ethiopia',
#  'Farm_1523_Ethiopia',
#  'Farm_1524_Ethiopia',
#  'Farm_1525_Ethiopia',
#  'Farm_1526_Ethiopia',
#  'Farm_1527_Ethiopia',
#  'Farm_1528_Ethiopia',
#  'Farm_1529_Ethiopia',
#  'Farm_152_Angola',
#  'Farm_1530_Ethiopia',
#  'Farm_1531_Ethiopia',
#  'Farm_1532_Ethiopia',
#  'Farm_1533_Ethiopia',
#  'Farm_1534_Ethiopia',
#  'Farm_1535_Ethiopia',
#  'Farm_1536_Ethiopia',
#  'Farm_1537_Ethiopia',
#  'Farm_1538_Ethiopia',
#  'Farm_1539_Ethiopia',
#  'Farm_153_Angola',
#  'Farm_1540_Ethiopia',
#  'Farm_1541_Ethiopia',
#  'Farm_1542_Ethiopia',
#  'Farm_1543_Ethiopia',
#  'Farm_1544_Ethiopia',
#  'Farm_1545_Ethiopia',
#  'Farm_1546_Ethiopia',
#  'Farm_1547_Ethiopia',
#  'Farm_1548_Ethiopia',
#  'Farm_1549_Ethiopia',
#  'Farm_154_Angola',
#  'Farm_1550_Ethiopia',
#  'Farm_1551_Ethiopia',
#  'Farm_1552_Ethiopia',
#  'Farm_1553_Ethiopia',
#  'Farm_1554_Ethiopia',
#  'Farm_1555_Ethiopia',
#  'Farm_1556_Ethiopia',
#  'Farm_1557_Ethiopia',
#  'Farm_1558_Ethiopia',
#  'Farm_1559_Ethiopia',
#  'Farm_155_Angola',
#  'Farm_1560_Ethiopia',
#  'Farm_1561_Ethiopia',
#  'Farm_1562_Ethiopia',
#  'Farm_1563_Ethiopia',
#  'Farm_1564_Ethiopia',
#  'Farm_1565_Ethiopia',
#  'Farm_1566_Ethiopia',
#  'Farm_1567_Ethiopia',
#  'Farm_1568_Ethiopia',
#  'Farm_1569_Ethiopia',
#  'Farm_156_Angola',
#  'Farm_1570_Ethiopia',
#  'Farm_1571_Ethiopia',
#  'Farm_1572_Ethiopia',
#  'Farm_1573_Ethiopia',
#  'Farm_1574_Ethiopia',
#  'Farm_1575_Ethiopia',
#  'Farm_1576_Ethiopia',
#  'Farm_1577_Ethiopia',
#  'Farm_1578_Ethiopia',
#  'Farm_1579_Ethiopia',
#  'Farm_157_Angola',
#  'Farm_1580_Ethiopia',
#  'Farm_1581_Ethiopia',
#  'Farm_1582_Ethiopia',
#  'Farm_1583_Ethiopia',
#  'Farm_1584_Ethiopia',
#  'Farm_1585_Ethiopia',
#  'Farm_1586_Ethiopia',
#  'Farm_1587_Ethiopia',
#  'Farm_1588_Ethiopia',
#  'Farm_1589_Ethiopia',
#  'Farm_158_Angola',
#  'Farm_1590_Ethiopia',
#  'Farm_1591_Ethiopia',
#  'Farm_1592_Ethiopia',
#  'Farm_1593_Ethiopia',
#  'Farm_1594_Ethiopia',
#  'Farm_1595_Ethiopia',
#  'Farm_1596_Ethiopia',
#  'Farm_1597_Ethiopia',
#  'Farm_1598_Ethiopia',
#  'Farm_1599_Ethiopia',
#  'Farm_159_Angola',
#  'Farm_15_Angola',
#  'Farm_1600_Ethiopia',
#  'Farm_1601_Ethiopia',
#  'Farm_1602_Ethiopia',
#  'Farm_1603_Ethiopia',
#  'Farm_1604_Ethiopia',
#  'Farm_1605_Ethiopia',
#  'Farm_1606_Ethiopia',
#  'Farm_1607_Ethiopia',
#  'Farm_1608_Ethiopia',
#  'Farm_1609_Ethiopia',
#  'Farm_160_Angola',
#  'Farm_1610_Ethiopia',
#  'Farm_1611_Ethiopia',
#  'Farm_1612_Ethiopia',
#  'Farm_1613_Ethiopia',
#  'Farm_1614_Ethiopia',
#  'Farm_1615_Ethiopia',
#  'Farm_1616_Ethiopia',
#  'Farm_1617_Ethiopia',
#  'Farm_1618_Ethiopia',
#  'Farm_1619_Ethiopia',
#  'Farm_161_Angola',
#  'Farm_1620_Ethiopia',
#  'Farm_1621_Ethiopia',
#  'Farm_1622_Ethiopia',
#  'Farm_1623_Ethiopia',
#  'Farm_1624_Ethiopia',
#  'Farm_1625_Ethiopia',
#  'Farm_1626_Ethiopia',
#  'Farm_1627_Ethiopia',
#  'Farm_1628_Ethiopia',
#  'Farm_1629_Ethiopia',
#  'Farm_162_Angola',
#  'Farm_1630_Ethiopia',
#  'Farm_1631_Ethiopia',
#  'Farm_1632_Ethiopia',
#  'Farm_1633_Ethiopia',
#  'Farm_1634_Ethiopia',
#  'Farm_1635_Ethiopia',
#  'Farm_1636_Ethiopia',
#  'Farm_1637_Ethiopia',
#  'Farm_1638_Ethiopia',
#  'Farm_1639_Ethiopia',
#  'Farm_163_Angola',
#  'Farm_1640_Ethiopia',
#  'Farm_1641_Ethiopia',
#  'Farm_1642_Ethiopia',
#  'Farm_1643_Ethiopia',
#  'Farm_1644_Ethiopia',
#  'Farm_1645_Ethiopia',
#  'Farm_1646_Ethiopia',
#  'Farm_1647_Ethiopia',
#  'Farm_1648_Ethiopia',
#  'Farm_1649_Ethiopia',
#  'Farm_164_Angola',
#  'Farm_1650_Ethiopia',
#  'Farm_1651_Ethiopia',
#  'Farm_1652_Ethiopia',
#  'Farm_1653_Ethiopia',
#  'Farm_1654_Ethiopia',
#  'Farm_1655_Ethiopia',
#  'Farm_1656_Ethiopia',
#  'Farm_1657_Ethiopia',
#  'Farm_1658_Ethiopia',
#  'Farm_1659_Ethiopia',
#  'Farm_165_Angola',
#  'Farm_1660_Ethiopia',
#  'Farm_1661_Ethiopia',
#  'Farm_1662_Ethiopia',
#  'Farm_1663_Ethiopia',
#  'Farm_1664_Ethiopia',
#  'Farm_1665_Ethiopia',
#  'Farm_1666_Ethiopia',
#  'Farm_1667_Ethiopia',
#  'Farm_1668_Ethiopia',
#  'Farm_1669_Ethiopia',
#  'Farm_166_Angola',
#  'Farm_1670_Ethiopia',
#  'Farm_1671_Ethiopia',
#  'Farm_1672_Ethiopia',
#  'Farm_1673_Ethiopia',
#  'Farm_1674_Ethiopia',
#  'Farm_1675_Ethiopia',
#  'Farm_1676_Ethiopia',
#  'Farm_1677_Ethiopia',
#  'Farm_1678_Ethiopia',
#  'Farm_1679_Ethiopia',
#  'Farm_167_Angola',
#  'Farm_1680_Ethiopia',
#  'Farm_1681_Ethiopia',
#  'Farm_1682_Ethiopia',
#  'Farm_1683_Ethiopia',
#  'Farm_1684_Ethiopia',
#  'Farm_1685_Ethiopia',
#  'Farm_1686_Ethiopia',
#  'Farm_1687_Ethiopia',
#  'Farm_1688_Ethiopia',
#  'Farm_1689_Ethiopia',
#  'Farm_168_Angola',
#  'Farm_1690_Ethiopia',
#  'Farm_1691_Ethiopia',
#  'Farm_1692_Ethiopia',
#  'Farm_1693_Ethiopia',
#  'Farm_1694_Ethiopia',
#  'Farm_1695_Ethiopia',
#  'Farm_1696_Ethiopia',
#  'Farm_1697_Ethiopia',
#  'Farm_1698_Ethiopia',
#  'Farm_1699_Ethiopia',
#  'Farm_169_Angola',
#  'Farm_16_Angola',
#  'Farm_1700_Ethiopia',
#  'Farm_1701_Ethiopia',
#  'Farm_1702_Ethiopia',
#  'Farm_1703_Ethiopia',
#  'Farm_1704_Ethiopia',
#  'Farm_1705_Ethiopia',
#  'Farm_1706_Ethiopia',
#  'Farm_1707_Ethiopia',
#  'Farm_1708_Ethiopia',
#  'Farm_1709_Ethiopia',
#  'Farm_170_Angola',
#  'Farm_1710_Ethiopia',
#  'Farm_1711_Ethiopia',
#  'Farm_1712_Ethiopia',
#  'Farm_1713_Ethiopia',
#  'Farm_1714_Ethiopia',
#  'Farm_1715_Ethiopia',
#  'Farm_1716_Ethiopia',
#  'Farm_1717_Ethiopia',
#  'Farm_1718_Ethiopia',
#  'Farm_1719_Ethiopia',
#  'Farm_171_Angola',
#  'Farm_1720_Ethiopia',
#  'Farm_1721_Ethiopia',
#  'Farm_1722_Ethiopia',
#  'Farm_1723_Ethiopia',
#  'Farm_1724_Ethiopia',
#  'Farm_1725_Ethiopia',
#  'Farm_1726_Ethiopia',
#  'Farm_1727_Ethiopia',
#  'Farm_1728_Ethiopia',
#  'Farm_1729_Ethiopia',
#  'Farm_172_Angola',
#  'Farm_1730_Ethiopia',
#  'Farm_1731_Ethiopia',
#  'Farm_1732_Ethiopia',
#  'Farm_1733_Ethiopia',
#  'Farm_1734_Ethiopia',
#  'Farm_1735_Ethiopia',
#  'Farm_1736_Ethiopia',
#  'Farm_1737_Ethiopia',
#  'Farm_1738_Ethiopia',
#  'Farm_1739_Ethiopia',
#  'Farm_173_Angola',
#  'Farm_1740_Ethiopia',
#  'Farm_1741_Ethiopia',
#  'Farm_1742_Ethiopia',
#  'Farm_1743_Ethiopia',
#  'Farm_1744_Ethiopia',
#  'Farm_1745_Ethiopia',
#  'Farm_1746_Gabon',
#  'Farm_1747_Gabon',
#  'Farm_1748_Gabon',
#  'Farm_1749_Gabon',
#  'Farm_174_Angola',
#  'Farm_1750_Gabon',
#  'Farm_1751_Gabon',
#  'Farm_1752_Gabon',
#  'Farm_1753_Gabon',
#  'Farm_1754_Gabon',
#  'Farm_1755_Gabon',
#  'Farm_1756_Gabon',
#  'Farm_1757_Gabon',
#  'Farm_1758_Gabon',
#  'Farm_1759_Gabon',
#  'Farm_175_Angola',
#  'Farm_1760_Gabon',
#  'Farm_1761_Gabon',
#  'Farm_1762_Gabon',
#  'Farm_1763_Gabon',
#  'Farm_1764_Gabon',
#  'Farm_1765_Gabon',
#  'Farm_1766_Gabon',
#  'Farm_1767_Gabon',
#  'Farm_1768_Gabon',
#  'Farm_1769_Gabon',
#  'Farm_176_Angola',
#  'Farm_1770_Gabon',
#  'Farm_1771_Gabon',
#  'Farm_1772_Gabon',
#  'Farm_1773_Gabon',
#  'Farm_1774_Gabon',
#  'Farm_1775_Gabon',
#  'Farm_1776_Gabon',
#  'Farm_1777_Gabon',
#  'Farm_1778_Gabon',
#  'Farm_1779_Gabon',
#  'Farm_177_Angola',
#  'Farm_1780_Gabon',
#  'Farm_1781_Gabon',
#  'Farm_1782_Gabon',
#  'Farm_1783_Gabon',
#  'Farm_1784_Gabon',
#  'Farm_1785_Gabon',
#  'Farm_1786_Gabon',
#  'Farm_1787_Gabon',
#  'Farm_1788_Gabon',
#  'Farm_1789_Gabon',
#  'Farm_178_Angola',
#  'Farm_1790_Gabon',
#  'Farm_1791_Gabon',
#  'Farm_1792_Gabon',
#  'Farm_1793_Gabon',
#  'Farm_1794_Gabon',
#  'Farm_1795_Gabon',
#  'Farm_1796_Gabon',
#  'Farm_1797_Gabon',
#  'Farm_1798_Gabon',
#  'Farm_1799_Gabon',
#  ...]

# %%
df_onehot.shape
# Out:
# (32359, 4000)

# %% [markdown]
# ## Train-test split

# %%
# Separate a test set, the year 2016
test = df_onehot[df_onehot.Year == 2016]
df_onehot_train = df_onehot[df_onehot.Year != 2016]

# %%
print('The training set has years: ', list(df_onehot_train.Year.unique()))
print('The test set has years: ', list(test.Year.unique()))
# Out:
# The training set has years:  [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# The test set has years:  [2016]

# %% [markdown]
# ## Cross-validation setup

# %%
# https://stackoverflow.com/questions/58069691/how-to-create-a-train-test-split-of-time-series-data-by-year

year_list = df_onehot_train['Year'].unique().tolist()
splits = {'train': [], 'val': []}

print('Time series CV split set-up:')

for idx, yr in enumerate(year_list[:-1]):
    if yr < 2010:
        # To get only the last 5 splits
        continue
    train_yr = year_list[:idx+1]
    test_yr = [year_list[idx+1]]
    print('TRAIN: ', train_yr, 'VAL: ',test_yr)
    
    splits['train'].append(df_onehot_train.loc[df_onehot_train.Year.isin(train_yr), :])
    splits['val'].append(df_onehot_train.loc[df_onehot_train.Year.isin(test_yr), :])
# Out:
# Time series CV split set-up:
# TRAIN:  [2007, 2008, 2009, 2010] VAL:  [2011]
# TRAIN:  [2007, 2008, 2009, 2010, 2011] VAL:  [2012]
# TRAIN:  [2007, 2008, 2009, 2010, 2011, 2012] VAL:  [2013]
# TRAIN:  [2007, 2008, 2009, 2010, 2011, 2012, 2013] VAL:  [2014]
# TRAIN:  [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014] VAL:  [2015]

# %% [markdown]
# Baseline selection

# %%
SEED = 1

# %%
regressors = {
    "KNN": KNeighborsRegressor(n_neighbors=5), # 1
    "Random Forest": RandomForestRegressor(n_estimators=50, random_state=SEED), # 2
    "Gradient Boosting": AdaBoostRegressor(n_estimators=50, random_state=SEED) # 3
}

# %%
# This will take about 50 minutes

reg_names = []
cv_MAE = []
cv_RMSE = []
cv_folds = []

i = 1
for train, val in zip(splits['train'], splits['val']):

    print('Fold: ', i)
    i += 1

    # Shuffle
    train = train.sample(frac=1, random_state=SEED)
    val = val.sample(frac=1, random_state=SEED)
    
    # X and y
    X_train = train.drop(columns=['Y_maize_major','Year'], axis=1)
    y_train = train['Y_maize_major']
    X_val = val.drop(columns=['Y_maize_major','Year'], axis=1)
    y_val = val['Y_maize_major']

    # Scale to [0,1] range
    sc = MinMaxScaler()
    X_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)
    X_val = pd.DataFrame(sc.transform(X_val), columns=X_val.columns)

    # Fit and predict
    for reg_name, reg in regressors.items():
        reg_names.append(reg_name)
        reg.fit(X_train, y_train)
        y_val_pred = reg.predict(X_val)
        rmse = mean_squared_error(y_val, y_val_pred, squared=False)
        mae = mean_absolute_error(y_val, y_val_pred)
        cv_MAE.append(mae)
        cv_RMSE.append(rmse)
        cv_folds.append(i)

        print(reg_name)
        print('RMSE:', rmse)
        print('MAE:', mae)

    print('###')
    print()
# Out:
# Fold:  1
# KNN
# RMSE: 0.3819310056677642
# MAE: 0.24173904248839592
# Random Forest
# RMSE: 0.39642733142417036
# MAE: 0.2423667388154175
# Gradient Boosting
# RMSE: 0.5000855467877465
# MAE: 0.4129980989777344
# ###
#
# Fold:  2
# KNN
# RMSE: 0.3849340563407218
# MAE: 0.2447192015488737
# Random Forest
# RMSE: 0.3912447027822915
# MAE: 0.23087309833790448
# Gradient Boosting
# RMSE: 0.5235330671948287
# MAE: 0.386980821826822
# ###
#
# Fold:  3
# KNN
# RMSE: 0.3769166279858769
# MAE: 0.23379424911092153
# Random Forest
# RMSE: 0.3355819462990291
# MAE: 0.24710307446589763
# Gradient Boosting
# RMSE: 0.397042306915879
# MAE: 0.3170888233947578
# ###
#
# Fold:  4
# KNN
# RMSE: 0.4735101670784505
# MAE: 0.3118770154295563
# Random Forest
# RMSE: 0.4197073395957634
# MAE: 0.24009060730609508
# Gradient Boosting
# RMSE: 0.4584248635750323
# MAE: 0.3261539418044919
# ###
#
# Fold:  5
# KNN
# RMSE: 0.5710344396435931
# MAE: 0.3310747787822485
# Random Forest
# RMSE: 0.5093437565445893
# MAE: 0.2629358587462299
# Gradient Boosting
# RMSE: 0.5878586229400512
# MAE: 0.40009875675212236
# ###

# %%
df_results = pd.DataFrame()
df_results['fold'] = cv_folds
df_results['regressor'] = reg_names
df_results['RMSE'] = cv_RMSE
df_results['MAE'] = cv_MAE
df_results
# Out:
#     fold          regressor      RMSE       MAE
# 0      2                KNN  0.381931  0.241739
# 1      2      Random Forest  0.396427  0.242367
# 2      2  Gradient Boosting  0.500086  0.412998
# 3      3                KNN  0.384934  0.244719
# 4      3      Random Forest  0.391245  0.230873
# 5      3  Gradient Boosting  0.523533  0.386981
# 6      4                KNN  0.376917  0.233794
# 7      4      Random Forest  0.335582  0.247103
# 8      4  Gradient Boosting  0.397042  0.317089
# 9      5                KNN  0.473510  0.311877
# 10     5      Random Forest  0.419707  0.240091
# 11     5  Gradient Boosting  0.458425  0.326154
# 12     6                KNN  0.571034  0.331075
# 13     6      Random Forest  0.509344  0.262936
# 14     6  Gradient Boosting  0.587859  0.400099

# %%
df_results.to_csv('baseline_selection_results.csv',index=False)

# %%
df_results.groupby('regressor').agg({'RMSE': ['min', 'max', 'mean'], 'MAE': ['min', 'max', 'mean']})
# Out:
#                        RMSE                           MAE
#                         min       max      mean       min       max      mean
# regressor
# Gradient Boosting  0.397042  0.587859  0.493389  0.317089  0.412998  0.368664
# KNN                0.376917  0.571034  0.437665  0.233794  0.331075  0.272641
# Random Forest      0.335582  0.509344  0.410461  0.230873  0.262936  0.244674

# %% [markdown]
# As we can see, Random Forest has the best performance in both RMSE and MAE. Mean CV RMSE is 0.410461. Mean CV MAE is 0.244674.

# %% [markdown]
# ## Refit Random Forest on train and predict on test set

# %%
# Shuffle
train = df_onehot_train.sample(frac=1, random_state=SEED)
test = test.sample(frac=1, random_state=SEED)

# X and y
X_train = train.drop(columns=['Y_maize_major','Year'], axis=1)
y_train = train['Y_maize_major']
X_test = test.drop(columns=['Y_maize_major','Year'], axis=1)
y_test = test['Y_maize_major']

# Scale to [0,1] range
sc = MinMaxScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(sc.transform(X_test), columns=X_test.columns)

# %%
# Fit on train and predict on test
reg = regressors['Random Forest']
reg.fit(X_train, y_train)
y_test_pred = reg.predict(X_test)

# %%
# Calculate and print metrics
rmse = mean_squared_error(y_test, y_test_pred, squared=False)
mae = mean_absolute_error(y_test, y_test_pred)
print('Performance on test set (year 2016) (baseline results)')
print('RMSE:', rmse)
print('MAE:', mae)
# Out:
# Performance on test set (year 2016) (baseline results)
# RMSE: 0.34957354478142083
# MAE: 0.2037005796011297

# %%
result_example = X_test.copy(deep=True)
result_example.insert(0, "y_pred", y_test_pred)
result_example.insert(0, "y_true", list(y_test))
result_example = result_example[result_example['Country_Democratic Republic of the Congo']==True]
result_example = result_example.loc[:,~result_example.columns.str.startswith('Country')]
result_example = result_example.loc[:,~result_example.columns.str.startswith('Farm')]
print('An example of true harvest maize major and predicted value for farms in Congo for year 2016:')
result_example.head(10)
# Out:
# An example of true harvest maize major and predicted value for farms in Congo for year 2016:
#       y_true    y_pred    Sand_1    Sand_2    Sand_3    Sand_4    Sand_5  \
# 8   0.743546  0.678138  0.707692  0.716418  0.701493  0.696970  0.691176
# 9   0.929391  0.889212  0.553846  0.567164  0.552239  0.530303  0.500000
# 10  0.773282  0.630775  0.476923  0.507463  0.492537  0.469697  0.455882
# 11  1.196573  1.221125  0.507692  0.537313  0.522388  0.500000  0.470588
# 13  0.627577  0.631528  0.661538  0.671642  0.686567  0.666667  0.617647
# 36  0.973832  0.998984  0.507692  0.522388  0.507463  0.454545  0.426471
# 40  1.035206  1.029772  0.676923  0.686567  0.671642  0.681818  0.647059
# 43  1.102481  1.089537  0.476923  0.492537  0.477612  0.454545  0.441176
# 44  0.959340  0.971366  0.538462  0.552239  0.537313  0.484848  0.470588
# 52  1.342746  1.643682  0.292308  0.313433  0.298507  0.287879  0.294118
#
#       Sand_6    Sand_7    Clay_1  ...  spi_12mon_8  spi_12mon_9  spi_12mon_10  \
# 8   0.691176  0.696970  0.333333  ...     0.514627     0.524026      0.547731
# 9   0.485294  0.484848  0.470588  ...     0.286514     0.283456      0.275987
# 10  0.455882  0.454545  0.549020  ...     0.425017     0.421177      0.371739
# 11  0.485294  0.484848  0.450980  ...     0.323139     0.336894      0.374060
# 13  0.617647  0.606061  0.333333  ...     0.324695     0.312411      0.323476
# 36  0.411765  0.424242  0.490196  ...     0.480912     0.475134      0.472899
# 40  0.647059  0.651515  0.372549  ...     0.393324     0.347569      0.351349
# 43  0.441176  0.424242  0.549020  ...     0.318601     0.307776      0.318799
# 44  0.470588  0.469697  0.450980  ...     0.345740     0.341380      0.375738
# 52  0.294118  0.318182  0.607843  ...     0.600942     0.608665      0.586783
#
#     spi_12mon_11  spi_12mon_12  Sow_Maize_month_int  Harvest_Maize_month_int  \
# 8       0.586617      0.552612             0.545455                      0.0
# 9       0.316065      0.292958             0.545455                      0.0
# 10      0.418382      0.386626             0.545455                      0.0
# 11      0.417048      0.395140             0.545455                      0.0
# 13      0.337261      0.339365             0.545455                      0.0
# 36      0.523768      0.443548             0.545455                      0.0
# 40      0.378513      0.349365             0.545455                      0.0
# 43      0.341581      0.324272             0.545455                      0.0
# 44      0.430789      0.414329             0.545455                      0.0
# 52      0.549201      0.441641             0.545455                      0.0
#
#     maize_lag-1  maize_lag-2  maize_lag-3
# 8      0.044966     0.048402     0.046394
# 9      0.064482     0.064086     0.065058
# 10     0.033285     0.059246     0.058882
# 11     0.086362     0.085510     0.087031
# 13     0.042617     0.045255     0.044097
# 36     0.065079     0.070121     0.073200
# 40     0.072267     0.073191     0.072435
# 43     0.079209     0.077729     0.078492
# 44     0.069983     0.067050     0.069090
# 52     0.088017     0.171576     0.160413
#
# [10 rows x 83 columns]
