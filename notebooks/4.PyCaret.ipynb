# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pycaret
from pycaret.regression import *

# %%
# check installed version
pycaret.__version__
# Out:
# '3.2.0'

# %%
# Load prepared data
df = pd.read_csv('../data/df_prepped.csv')
df.head()
# Out:
#    Year Countries  Sand_1  Sand_2  Sand_3  Sand_4  Sand_5  Sand_6  Sand_7  \
# 0  2007    Angola      50      51      51      48      45      46      46
# 1  2007    Angola      62      64      63      59      58      59      59
# 2  2007    Angola      69      71      70      67      65      65      66
# 3  2007    Angola      60      63      61      57      53      53      53
# 4  2007    Angola      67      69      68      63      61      61      61
#
#    Clay_1  ...   tmax_mean   tmin_mean  spi_mean  maize_lag-1  maize_lag-2  \
# 0      37  ...  301.525359  292.421194  0.925277     0.554392     0.721607
# 1      27  ...  304.262436  288.525057  0.685189     0.117051     0.300217
# 2      19  ...  305.844360  290.321532 -0.117002     3.093239     4.044452
# 3      29  ...  299.110089  287.426233  0.417313     0.677797     0.907431
# 4      22  ...  304.329997  290.368481  1.314301     0.412071     0.675967
#
#    maize_lag-3  pcp_mean_lag-1  tmax_mean_lag-1  tmix_mean_lag-1  \
# 0     0.620005       97.103755       301.939623       292.214020
# 1     0.212699       59.292237       301.882929       288.092753
# 2     2.295351       58.196545       302.891420       289.377311
# 3     0.783018      149.210195       298.973795       287.311403
# 4     0.605584       74.556629       304.006860       290.606725
#
#    spi_mean_lag-1
# 0        0.093447
# 1        0.182926
# 2        0.991663
# 3        0.206751
# 4       -0.075621
#
# [5 rows x 46 columns]

# %%
print('Dataframe shape: ', df.shape)
print('Num unique countries: ', df.Countries.nunique())
print('Num unique farms: ', df.Farm.nunique())
print('Num unique years: ', df.Year.nunique())
print('Years: ', list(df.Year.unique()))
# Out:
# Dataframe shape:  (32359, 46)
# Num unique countries:  30
# Num unique farms:  3887
# Num unique years:  10
# Years:  [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
# Drop Countries and Farm
df_label = df.loc[:,['Countries','Farm']]
df = df.drop(['Countries','Farm'], axis=1)

# %%
# Separate a test set, the year 2016
df_test = df[df.Year == 2016].sort_values('Year')
df_train = df[df.Year != 2016]

print('The training set has years: ', list(df_train.Year.unique()))
print('The test set has years: ', list(df_test.Year.unique()))
# Out:
# The training set has years:  [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# The test set has years:  [2016]

# %%
df_test.shape, df_train.shape
# Out:
# ((2930, 44), (29429, 44))

# %% [markdown]
# ## Pycaret

# %%
# init setup
s = setup(data=df_train, 
          test_data = df_test, 
          target = 'Y_maize_major', 
          fold = 5, 
          normalize = True,
          normalize_method = 'robust',
          session_id = 123)
# Out:
# <style type="text/css">
# #T_9dcfc_row8_col1, #T_9dcfc_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9dcfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9dcfc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9dcfc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dcfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9dcfc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9dcfc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9dcfc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9dcfc_row1_col1" class="data row1 col1" >Y_maize_major</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9dcfc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9dcfc_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9dcfc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9dcfc_row3_col1" class="data row3 col1" >(32359, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9dcfc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9dcfc_row4_col1" class="data row4 col1" >(32359, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9dcfc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9dcfc_row5_col1" class="data row5 col1" >(29429, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9dcfc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9dcfc_row6_col1" class="data row6 col1" >(2930, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9dcfc_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9dcfc_row7_col1" class="data row7 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9dcfc_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9dcfc_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9dcfc_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9dcfc_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9dcfc_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9dcfc_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9dcfc_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9dcfc_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9dcfc_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_9dcfc_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9dcfc_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_9dcfc_row13_col1" class="data row13 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9dcfc_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_9dcfc_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9dcfc_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_9dcfc_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9dcfc_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_9dcfc_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9dcfc_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_9dcfc_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9dcfc_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_9dcfc_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9dcfc_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_9dcfc_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9dcfc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9dcfc_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_9dcfc_row20_col1" class="data row20 col1" >0204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Select top N models (default hyperparameters, without tuning)
N = 5
best_N = compare_models(n_select = N, sort = 'MAE', exclude=['lar'])
# Out:
# <style type="text/css">
# #T_6167e th {
#   text-align: left;
# }
# #T_6167e_row0_col0, #T_6167e_row1_col0, #T_6167e_row1_col1, #T_6167e_row1_col2, #T_6167e_row1_col3, #T_6167e_row1_col4, #T_6167e_row1_col5, #T_6167e_row1_col6, #T_6167e_row2_col0, #T_6167e_row2_col1, #T_6167e_row2_col2, #T_6167e_row2_col3, #T_6167e_row2_col4, #T_6167e_row2_col5, #T_6167e_row2_col6, #T_6167e_row3_col0, #T_6167e_row3_col1, #T_6167e_row3_col2, #T_6167e_row3_col3, #T_6167e_row3_col4, #T_6167e_row3_col5, #T_6167e_row3_col6, #T_6167e_row4_col0, #T_6167e_row4_col1, #T_6167e_row4_col2, #T_6167e_row4_col3, #T_6167e_row4_col4, #T_6167e_row4_col5, #T_6167e_row4_col6, #T_6167e_row5_col0, #T_6167e_row5_col1, #T_6167e_row5_col2, #T_6167e_row5_col3, #T_6167e_row5_col4, #T_6167e_row5_col5, #T_6167e_row5_col6, #T_6167e_row6_col0, #T_6167e_row6_col1, #T_6167e_row6_col2, #T_6167e_row6_col3, #T_6167e_row6_col4, #T_6167e_row6_col5, #T_6167e_row6_col6, #T_6167e_row7_col0, #T_6167e_row7_col1, #T_6167e_row7_col2, #T_6167e_row7_col3, #T_6167e_row7_col4, #T_6167e_row7_col5, #T_6167e_row7_col6, #T_6167e_row8_col0, #T_6167e_row8_col1, #T_6167e_row8_col2, #T_6167e_row8_col3, #T_6167e_row8_col4, #T_6167e_row8_col5, #T_6167e_row8_col6, #T_6167e_row9_col0, #T_6167e_row9_col1, #T_6167e_row9_col2, #T_6167e_row9_col3, #T_6167e_row9_col4, #T_6167e_row9_col5, #T_6167e_row9_col6, #T_6167e_row10_col0, #T_6167e_row10_col1, #T_6167e_row10_col2, #T_6167e_row10_col3, #T_6167e_row10_col4, #T_6167e_row10_col5, #T_6167e_row10_col6, #T_6167e_row11_col0, #T_6167e_row11_col1, #T_6167e_row11_col2, #T_6167e_row11_col3, #T_6167e_row11_col4, #T_6167e_row11_col5, #T_6167e_row11_col6, #T_6167e_row12_col0, #T_6167e_row12_col1, #T_6167e_row12_col2, #T_6167e_row12_col3, #T_6167e_row12_col4, #T_6167e_row12_col5, #T_6167e_row12_col6, #T_6167e_row13_col0, #T_6167e_row13_col1, #T_6167e_row13_col2, #T_6167e_row13_col3, #T_6167e_row13_col4, #T_6167e_row13_col5, #T_6167e_row13_col6, #T_6167e_row14_col0, #T_6167e_row14_col1, #T_6167e_row14_col2, #T_6167e_row14_col3, #T_6167e_row14_col4, #T_6167e_row14_col5, #T_6167e_row14_col6, #T_6167e_row15_col0, #T_6167e_row15_col1, #T_6167e_row15_col2, #T_6167e_row15_col3, #T_6167e_row15_col4, #T_6167e_row15_col5, #T_6167e_row15_col6, #T_6167e_row16_col0, #T_6167e_row16_col1, #T_6167e_row16_col2, #T_6167e_row16_col3, #T_6167e_row16_col4, #T_6167e_row16_col5, #T_6167e_row16_col6 {
#   text-align: left;
# }
# #T_6167e_row0_col1, #T_6167e_row0_col2, #T_6167e_row0_col3, #T_6167e_row0_col4, #T_6167e_row0_col5, #T_6167e_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6167e_row0_col7, #T_6167e_row1_col7, #T_6167e_row3_col7, #T_6167e_row4_col7, #T_6167e_row5_col7, #T_6167e_row6_col7, #T_6167e_row7_col7, #T_6167e_row8_col7, #T_6167e_row9_col7, #T_6167e_row10_col7, #T_6167e_row11_col7, #T_6167e_row12_col7, #T_6167e_row13_col7, #T_6167e_row14_col7, #T_6167e_row15_col7, #T_6167e_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6167e_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6167e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6167e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6167e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6167e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6167e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6167e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6167e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6167e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6167e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6167e_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_6167e_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_6167e_row0_col1" class="data row0 col1" >0.2413</td>
#       <td id="T_6167e_row0_col2" class="data row0 col2" >0.1624</td>
#       <td id="T_6167e_row0_col3" class="data row0 col3" >0.3984</td>
#       <td id="T_6167e_row0_col4" class="data row0 col4" >0.9300</td>
#       <td id="T_6167e_row0_col5" class="data row0 col5" >0.1222</td>
#       <td id="T_6167e_row0_col6" class="data row0 col6" >0.1946</td>
#       <td id="T_6167e_row0_col7" class="data row0 col7" >0.4940</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_6167e_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_6167e_row1_col1" class="data row1 col1" >0.2513</td>
#       <td id="T_6167e_row1_col2" class="data row1 col2" >0.1664</td>
#       <td id="T_6167e_row1_col3" class="data row1 col3" >0.4026</td>
#       <td id="T_6167e_row1_col4" class="data row1 col4" >0.9288</td>
#       <td id="T_6167e_row1_col5" class="data row1 col5" >0.1256</td>
#       <td id="T_6167e_row1_col6" class="data row1 col6" >0.2156</td>
#       <td id="T_6167e_row1_col7" class="data row1 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_6167e_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_6167e_row2_col1" class="data row2 col1" >0.2526</td>
#       <td id="T_6167e_row2_col2" class="data row2 col2" >0.1736</td>
#       <td id="T_6167e_row2_col3" class="data row2 col3" >0.4131</td>
#       <td id="T_6167e_row2_col4" class="data row2 col4" >0.9242</td>
#       <td id="T_6167e_row2_col5" class="data row2 col5" >0.1255</td>
#       <td id="T_6167e_row2_col6" class="data row2 col6" >0.2104</td>
#       <td id="T_6167e_row2_col7" class="data row2 col7" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_6167e_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_6167e_row3_col1" class="data row3 col1" >0.2527</td>
#       <td id="T_6167e_row3_col2" class="data row3 col2" >0.1732</td>
#       <td id="T_6167e_row3_col3" class="data row3 col3" >0.4125</td>
#       <td id="T_6167e_row3_col4" class="data row3 col4" >0.9245</td>
#       <td id="T_6167e_row3_col5" class="data row3 col5" >0.1255</td>
#       <td id="T_6167e_row3_col6" class="data row3 col6" >0.2106</td>
#       <td id="T_6167e_row3_col7" class="data row3 col7" >3.1140</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_6167e_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_6167e_row4_col1" class="data row4 col1" >0.2527</td>
#       <td id="T_6167e_row4_col2" class="data row4 col2" >0.1744</td>
#       <td id="T_6167e_row4_col3" class="data row4 col3" >0.4140</td>
#       <td id="T_6167e_row4_col4" class="data row4 col4" >0.9236</td>
#       <td id="T_6167e_row4_col5" class="data row4 col5" >0.1256</td>
#       <td id="T_6167e_row4_col6" class="data row4 col6" >0.2104</td>
#       <td id="T_6167e_row4_col7" class="data row4 col7" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_6167e_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_6167e_row5_col1" class="data row5 col1" >0.2656</td>
#       <td id="T_6167e_row5_col2" class="data row5 col2" >0.1955</td>
#       <td id="T_6167e_row5_col3" class="data row5 col3" >0.4373</td>
#       <td id="T_6167e_row5_col4" class="data row5 col4" >0.9140</td>
#       <td id="T_6167e_row5_col5" class="data row5 col5" >0.1299</td>
#       <td id="T_6167e_row5_col6" class="data row5 col6" >0.2176</td>
#       <td id="T_6167e_row5_col7" class="data row5 col7" >8.7780</td>
#     </tr>
#     <tr>
#       <th id="T_6167e_level0_row6" class="row_heading level0 row6" >lightgbm</th>
#       <td id="T_6167e_row6_col0" class="data row6 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6167e_row6_col1" class="data row6 col1"

# %%
df_pycaret_results = pull()

# %%
df_pycaret_results.to_csv('../experiment_results/pycaret_cv.csv')

# %%
# Tune best models
best_N_tuned = [tune_model(model) for model in best_N]
# Out:
# <style type="text/css">
# #T_b9bcc_row5_col0, #T_b9bcc_row5_col1, #T_b9bcc_row5_col2, #T_b9bcc_row5_col3, #T_b9bcc_row5_col4, #T_b9bcc_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b9bcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9bcc_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b9bcc_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b9bcc_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b9bcc_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b9bcc_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b9bcc_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9bcc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9bcc_row0_col0" class="data row0 col0" >0.2126</td>
#       <td id="T_b9bcc_row0_col1" class="data row0 col1" >0.1369</td>
#       <td id="T_b9bcc_row0_col2" class="data row0 col2" >0.3701</td>
#       <td id="T_b9bcc_row0_col3" class="data row0 col3" >0.9056</td>
#       <td id="T_b9bcc_row0_col4" class="data row0 col4" >0.1233</td>
#       <td id="T_b9bcc_row0_col5" class="data row0 col5" >0.2167</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9bcc_row1_col0" class="data row1 col0" >0.2951</td>
#       <td id="T_b9bcc_row1_col1" class="data row1 col1" >0.2576</td>
#       <td id="T_b9bcc_row1_col2" class="data row1 col2" >0.5076</td>
#       <td id="T_b9bcc_row1_col3" class="data row1 col3" >0.9050</td>
#       <td id="T_b9bcc_row1_col4" class="data row1 col4" >0.1389</td>
#       <td id="T_b9bcc_row1_col5" class="data row1 col5" >0.2063</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9bcc_row2_col0" class="data row2 col0" >0.2462</td>
#       <td id="T_b9bcc_row2_col1" class="data row2 col1" >0.1326</td>
#       <td id="T_b9bcc_row2_col2" class="data row2 col2" >0.3641</td>
#       <td id="T_b9bcc_row2_col3" class="data row2 col3" >0.9436</td>
#       <td id="T_b9bcc_row2_col4" class="data row2 col4" >0.1231</td>
#       <td id="T_b9bcc_row2_col5" class="data row2 col5" >0.1766</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9bcc_row3_col0" class="data row3 col0" >0.2243</td>
#       <td id="T_b9bcc_row3_col1" class="data row3 col1" >0.1153</td>
#       <td id="T_b9bcc_row3_col2" class="data row3 col2" >0.3395</td>
#       <td id="T_b9bcc_row3_col3" class="data row3 col3" >0.9544</td>
#       <td id="T_b9bcc_row3_col4" class="data row3 col4" >0.1125</td>
#       <td id="T_b9bcc_row3_col5" class="data row3 col5" >0.1880</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9bcc_row4_col0" class="data row4 col0" >0.2218</td>
#       <td id="T_b9bcc_row4_col1" class="data row4 col1" >0.1677</td>
#       <td id="T_b9bcc_row4_col2" class="data row4 col2" >0.4095</td>
#       <td id="T_b9bcc_row4_col3" class="data row4 col3" >0.9410</td>
#       <td id="T_b9bcc_row4_col4" class="data row4 col4" >0.1125</td>
#       <td id="T_b9bcc_row4_col5" class="data row4 col5" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b9bcc_row5_col0" class="data row5 col0" >0.2400</td>
#       <td id="T_b9bcc_row5_col1" class="data row5 col1" >0.1620</td>
#       <td id="T_b9bcc_row5_col2" class="data row5 col2" >0.3982</td>
#       <td id="T_b9bcc_row5_col3" class="data row5 col3" >0.9299</td>
#       <td id="T_b9bcc_row5_col4" class="data row5 col4" >0.1220</td>
#       <td id="T_b9bcc_row5_col5" class="data row5 col5" >0.1939</td>
#     </tr>
#     <tr>
#       <th id="T_b9bcc_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b9bcc_row6_col0" class="data row6 col0" >0.0297</td>
#       <td id="T_b9bcc_row6_col1" class="data row6 col1" >0.0507</td>
#       <td id="T_b9bcc_row6_col2" class="data row6 col2" >0.0591</td>
#       <td id="T_b9bcc_row6_col3" class="data row6 col3" >0.0206</td>
#       <td id="T_b9bcc_row6_col4" class="data row6 col4" >0.0097</td>
#       <td id="T_b9bcc_row6_col5" class="data row6 col5" >0.0151</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_e74b8_row5_col0, #T_e74b8_row5_col1, #T_e74b8_row5_col2, #T_e74b8_row5_col3, #T_e74b8_row5_col4, #T_e74b8_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e74b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e74b8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e74b8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e74b8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e74b8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e74b8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e74b8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e74b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e74b8_row0_col0" class="data row0 col0" >0.2312</td>
#       <td id="T_e74b8_row0_col1" class="data row0 col1" >0.1557</td>
#       <td id="T_e74b8_row0_col2" class="data row0 col2" >0.3946</td>
#       <td id="T_e74b8_row0_col3" class="data row0 col3" >0.8926</td>
#       <td id="T_e74b8_row0_col4" class="data row0 col4" >0.1262</td>
#       <td id="T_e74b8_row0_col5" class="data row0 col5" >0.2517</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e74b8_row1_col0" class="data row1 col0" >0.3075</td>
#       <td id="T_e74b8_row1_col1" class="data row1 col1" >0.2668</td>
#       <td id="T_e74b8_row1_col2" class="data row1 col2" >0.5166</td>
#       <td id="T_e74b8_row1_col3" class="data row1 col3" >0.9016</td>
#       <td id="T_e74b8_row1_col4" class="data row1 col4" >0.1425</td>
#       <td id="T_e74b8_row1_col5" class="data row1 col5" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e74b8_row2_col0" class="data row2 col0" >0.2518</td>
#       <td id="T_e74b8_row2_col1" class="data row2 col1" >0.1378</td>
#       <td id="T_e74b8_row2_col2" class="data row2 col2" >0.3713</td>
#       <td id="T_e74b8_row2_col3" class="data row2 col3" >0.9414</td>
#       <td id="T_e74b8_row2_col4" class="data row2 col4" >0.1232</td>
#       <td id="T_e74b8_row2_col5" class="data row2 col5" >0.1892</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e74b8_row3_col0" class="data row3 col0" >0.2440</td>
#       <td id="T_e74b8_row3_col1" class="data row3 col1" >0.1352</td>
#       <td id="T_e74b8_row3_col2" class="data row3 col2" >0.3677</td>
#       <td id="T_e74b8_row3_col3" class="data row3 col3" >0.9465</td>
#       <td id="T_e74b8_row3_col4" class="data row3 col4" >0.1208</td>
#       <td id="T_e74b8_row3_col5" class="data row3 col5" >0.2027</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e74b8_row4_col0" class="data row4 col0" >0.2272</td>
#       <td id="T_e74b8_row4_col1" class="data row4 col1" >0.1677</td>
#       <td id="T_e74b8_row4_col2" class="data row4 col2" >0.4095</td>
#       <td id="T_e74b8_row4_col3" class="data row4 col3" >0.9410</td>
#       <td id="T_e74b8_row4_col4" class="data row4 col4" >0.1144</td>
#       <td id="T_e74b8_row4_col5" class="data row4 col5" >0.1867</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_e74b8_row5_col0" class="data row5 col0" >0.2523</td>
#       <td id="T_e74b8_row5_col1" class="data row5 col1" >0.1727</td>
#       <td id="T_e74b8_row5_col2" class="data row5 col2" >0.4119</td>
#       <td id="T_e74b8_row5_col3" class="data row5 col3" >0.9246</td>
#       <td id="T_e74b8_row5_col4" class="data row5 col4" >0.1254</td>
#       <td id="T_e74b8_row5_col5" class="data row5 col5" >0.2107</td>
#     </tr>
#     <tr>
#       <th id="T_e74b8_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_e74b8_row6_col0" class="data row6 col0" >0.0290</td>
#       <td id="T_e74b8_row6_col1" class="data row6 col1" >0.0486</td>
#       <td id="T_e74b8_row6_col2" class="data row6 col2" >0.0545</td>
#       <td id="T_e74b8_row6_col3" class="data row6 col3" >0.0227</td>
#       <td id="T_e74b8_row6_col4" class="data row6 col4" >0.0094</td>
#       <td id="T_e74b8_row6_col5" class="data row6 col5" >0.0242</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_db6ab_row5_col0, #T_db6ab_row5_col1, #T_db6ab_row5_col2, #T_db6ab_row5_col3, #T_db6ab_row5_col4, #T_db6ab_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_db6ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db6ab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_db6ab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_db6ab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_db6ab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_db6ab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_db6ab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db6ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db6ab_row0_col0" class="data row0 col0" >0.2314</td>
#       <td id="T_db6ab_row0_col1" class="data row0 col1" >0.1566</td>
#       <td id="T_db6ab_row0_col2" class="data row0 col2" >0.3957</td>
#       <td id="T_db6ab_row0_col3" class="data row0 col3" >0.8920</td>
#       <td id="T_db6ab_row0_col4" class="data row0 col4" >0.1263</td>
#       <td id="T_db6ab_row0_col5" class="data row0 col5" >0.2518</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db6ab_row1_col0" class="data row1 col0" >0.3076</td>
#       <td id="T_db6ab_row1_col1" class="data row1 col1" >0.2684</td>
#       <td id="T_db6ab_row1_col2" class="data row1 col2" >0.5180</td>
#       <td id="T_db6ab_row1_col3" class="data row1 col3" >0.9010</td>
#       <td id="T_db6ab_row1_col4" class="data row1 col4" >0.1425</td>
#       <td id="T_db6ab_row1_col5" class="data row1 col5" >0.2219</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db6ab_row2_col0" class="data row2 col0" >0.2522</td>
#       <td id="T_db6ab_row2_col1" class="data row2 col1" >0.1382</td>
#       <td id="T_db6ab_row2_col2" class="data row2 col2" >0.3718</td>
#       <td id="T_db6ab_row2_col3" class="data row2 col3" >0.9412</td>
#       <td id="T_db6ab_row2_col4" class="data row2 col4" >0.1234</td>
#       <td id="T_db6ab_row2_col5" class="data row2 col5" >0.1892</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db6ab_row3_col0" class="data row3 col0" >0.2447</td>
#       <td id="T_db6ab_row3_col1" class="data row3 col1" >0.1361</td>
#       <td id="T_db6ab_row3_col2" class="data row3 col2" >0.3690</td>
#       <td id="T_db6ab_row3_col3" class="data row3 col3" >0.9462</td>
#       <td id="T_db6ab_row3_col4" class="data row3 col4" >0.1210</td>
#       <td id="T_db6ab_row3_col5" class="data row3 col5" >0.2030</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db6ab_row4_col0" class="data row4 col0" >0.2273</td>
#       <td id="T_db6ab_row4_col1" class="data row4 col1" >0.1677</td>
#       <td id="T_db6ab_row4_col2" class="data row4 col2" >0.4095</td>
#       <td id="T_db6ab_row4_col3" class="data row4 col3" >0.9410</td>
#       <td id="T_db6ab_row4_col4" class="data row4 col4" >0.1144</td>
#       <td id="T_db6ab_row4_col5" class="data row4 col5" >0.1865</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_db6ab_row5_col0" class="data row5 col0" >0.2526</td>
#       <td id="T_db6ab_row5_col1" class="data row5 col1" >0.1734</td>
#       <td id="T_db6ab_row5_col2" class="data row5 col2" >0.4128</td>
#       <td id="T_db6ab_row5_col3" class="data row5 col3" >0.9243</td>
#       <td id="T_db6ab_row5_col4" class="data row5 col4" >0.1255</td>
#       <td id="T_db6ab_row5_col5" class="data row5 col5" >0.2105</td>
#     </tr>
#     <tr>
#       <th id="T_db6ab_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_db6ab_row6_col0" class="data row6 col0" >0.0289</td>
#       <td id="T_db6ab_row6_col1" class="data row6 col1" >0.0489</td>
#       <td id="T_db6ab_row6_col2" class="data row6 col2" >0.0547</td>
#       <td id="T_db6ab_row6_col3" class="data row6 col3" >0.0229</td>
#       <td id="T_db6ab_row6_col4" class="data row6 col4" >0.0093</td>
#       <td id="T_db6ab_row6_col5" class="data row6 col5" >0.0242</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# <style type="text/css">
# #T_db268_row5_col0, #T_db268_row5_col1, #T_db268_row5_col2, #T_db268_row5_col3, #T_db268_row5_col4, #T_db268_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_db268">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db268_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_db268_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_db268_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_db268_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_db268_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_db268_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db268_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db268_row0_col0" class="data row0 col0" >0.2311</td>
#       <td id="T_db268_row0_col1" class="data row0 col1" >0.1553</td>
#       <td id="T_db268_row0_col2" class="data row0 col2" >0.3940</td>
#       <td id="T_db268_row0_col3" class="data row0 col3" >0.8929</td>
#       <td id="T_db268_row0_col4" class="data row0 col4" >0.1262</td>
#       <td id="T_db268_row0_col5" class="data row0 col5" >0.2516</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db268_row1_col0" class="data row1 col0" >0.3076</td>
#       <td id="T_db268_row1_col1" class="data row1 col1" >0.2682</td>
#       <td id="T_db268_row1_col2" class="data row1 col2" >0.5179</td>
#       <td id="T_db268_row1_col3" class="data row1 col3" >0.9011</td>
#       <td id="T_db268_row1_col4" class="data row1 col4" >0.1424</td>
#       <td id="T_db268_row1_col5" class="data row1 col5" >0.2220</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db268_row2_col0" class="data row2 col0" >0.2524</td>
#       <td id="T_db268_row2_col1" class="data row2 col1" >0.1385</td>
#       <td id="T_db268_row2_col2" class="data row2 col2" >0.3721</td>
#       <td id="T_db268_row2_col3" class="data row2 col3" >0.9411</td>
#       <td id="T_db268_row2_col4" class="data row2 col4" >0.1235</td>
#       <td id="T_db268_row2_col5" class="data row2 col5" >0.1895</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db268_row3_col0" class="data row3 col0" >0.2449</td>
#       <td id="T_db268_row3_col1" class="data row3 col1" >0.1362</td>
#       <td id="T_db268_row3_col2" class="data row3 col2" >0.3690</td>
#       <td id="T_db268_row3_col3" class="data row3 col3" >0.9462</td>
#       <td id="T_db268_row3_col4" class="data row3 col4" >0.1211</td>
#       <td id="T_db268_row3_col5" class="data row3 col5" >0.2033</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db268_row4_col0" class="data row4 col0" >0.2274</td>
#       <td id="T_db268_row4_col1" class="data row4 col1" >0.1678</td>
#       <td id="T_db268_row4_col2" class="data row4 col2" >0.4096</td>
#       <td id="T_db268_row4_col3" class="data row4 col3" >0.9410</td>
#       <td id="T_db268_row4_col4" class="data row4 col4" >0.1144</td>
#       <td id="T_db268_row4_col5" class="data row4 col5" >0.1866</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_db268_row5_col0" class="data row5 col0" >0.2527</td>
#       <td id="T_db268_row5_col1" class="data row5 col1" >0.1732</td>
#       <td id="T_db268_row5_col2" class="data row5 col2" >0.4125</td>
#       <td id="T_db268_row5_col3" class="data row5 col3" >0.9245</td>
#       <td id="T_db268_row5_col4" class="data row5 col4" >0.1255</td>
#       <td id="T_db268_row5_col5" class="data row5 col5" >0.2106</td>
#     </tr>
#     <tr>
#       <th id="T_db268_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_db268_row6_col0" class="data row6 col0" >0.0289</td>
#       <td id="T_db268_row6_col1" class="data row6 col1" >0.0489</td>
#       <td id="T_db268_row6_col2" class="data row6 col2" >0.0547</td>
#       <td id="T_db268_row6_col3" class="data row6 col3" >0.0226</td>
#       <td id="T_db268_row6_col4" class="data row6 col4" >0.0093</td>
#       <td id="T_db268_row6_col5" class="data row6 col5" >0.0240</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_07a7b_row5_col0, #T_07a7b_row5_col1, #T_07a7b_row5_col2, #T_07a7b_row5_col3, #T_07a7b_row5_col4, #T_07a7b_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_07a7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07a7b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_07a7b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_07a7b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_07a7b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_07a7b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_07a7b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07a7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07a7b_row0_col0" class="data row0 col0" >0.2322</td>
#       <td id="T_07a7b_row0_col1" class="data row0 col1" >0.1604</td>
#       <td id="T_07a7b_row0_col2" class="data row0 col2" >0.4005</td>
#       <td id="T_07a7b_row0_col3" class="data row0 col3" >0.8894</td>
#       <td id="T_07a7b_row0_col4" class="data row0 col4" >0.1267</td>
#       <td id="T_07a7b_row0_col5" class="data row0 col5" >0.2529</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07a7b_row1_col0" class="data row1 col0" >0.3077</td>
#       <td id="T_07a7b_row1_col1" class="data row1 col1" >0.2689</td>
#       <td id="T_07a7b_row1_col2" class="data row1 col2" >0.5186</td>
#       <td id="T_07a7b_row1_col3" class="data row1 col3" >0.9008</td>
#       <td id="T_07a7b_row1_col4" class="data row1 col4" >0.1425</td>
#       <td id="T_07a7b_row1_col5" class="data row1 col5" >0.2214</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07a7b_row2_col0" class="data row2 col0" >0.2519</td>
#       <td id="T_07a7b_row2_col1" class="data row2 col1" >0.1380</td>
#       <td id="T_07a7b_row2_col2" class="data row2 col2" >0.3715</td>
#       <td id="T_07a7b_row2_col3" class="data row2 col3" >0.9413</td>
#       <td id="T_07a7b_row2_col4" class="data row2 col4" >0.1232</td>
#       <td id="T_07a7b_row2_col5" class="data row2 col5" >0.1889</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07a7b_row3_col0" class="data row3 col0" >0.2444</td>
#       <td id="T_07a7b_row3_col1" class="data row3 col1" >0.1361</td>
#       <td id="T_07a7b_row3_col2" class="data row3 col2" >0.3689</td>
#       <td id="T_07a7b_row3_col3" class="data row3 col3" >0.9462</td>
#       <td id="T_07a7b_row3_col4" class="data row3 col4" >0.1209</td>
#       <td id="T_07a7b_row3_col5" class="data row3 col5" >0.2026</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07a7b_row4_col0" class="data row4 col0" >0.2272</td>
#       <td id="T_07a7b_row4_col1" class="data row4 col1" >0.1677</td>
#       <td id="T_07a7b_row4_col2" class="data row4 col2" >0.4095</td>
#       <td id="T_07a7b_row4_col3" class="data row4 col3" >0.9410</td>
#       <td id="T_07a7b_row4_col4" class="data row4 col4" >0.1144</td>
#       <td id="T_07a7b_row4_col5" class="data row4 col5" >0.1863</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_07a7b_row5_col0" class="data row5 col0" >0.2527</td>
#       <td id="T_07a7b_row5_col1" class="data row5 col1" >0.1742</td>
#       <td id="T_07a7b_row5_col2" class="data row5 col2" >0.4138</td>
#       <td id="T_07a7b_row5_col3" class="data row5 col3" >0.9237</td>
#       <td id="T_07a7b_row5_col4" class="data row5 col4" >0.1255</td>
#       <td id="T_07a7b_row5_col5" class="data row5 col5" >0.2104</td>
#     </tr>
#     <tr>
#       <th id="T_07a7b_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_07a7b_row6_col0" class="data row6 col0" >0.0289</td>
#       <td id="T_07a7b_row6_col1" class="data row6 col1" >0.0489</td>
#       <td id="T_07a7b_row6_col2" class="data row6 col2" >0.0547</td>
#       <td id="T_07a7b_row6_col3" class="data row6 col3" >0.0237</td>
#       <td id="T_07a7b_row6_col4" class="data row6 col4" >0.0094</td>
#       <td id="T_07a7b_row6_col5" class="data row6 col5" >0.0246</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
top_3_models = compare_models(n_select = 3, sort = 'MAE', include=best_N_tuned)

# %%
df_pycaret_cv_with_tuning = pull()

# %%
df_pycaret_cv_with_tuning
# Out:
#                          Model     MAE     MSE    RMSE      R2   RMSLE  \
# 0              Huber Regressor  0.2413  0.1624  0.3984  0.9300  0.1222
# 1  Orthogonal Matching Pursuit  0.2513  0.1664  0.4026  0.9288  0.1256
# 2             Ridge Regression  0.2526  0.1734  0.4128  0.9243  0.1255
# 3            Linear Regression  0.2527  0.1732  0.4125  0.9245  0.1255
# 4               Bayesian Ridge  0.2527  0.1742  0.4138  0.9237  0.1255
#
#      MAPE  TT (Sec)
# 0  0.1946     0.530
# 1  0.2156     0.068
# 2  0.2105     0.072
# 3  0.2106     0.084
# 4  0.2104     0.114

# %%
df_pycaret_cv_with_tuning.to_csv('../experiment_results/pycaret_cv_with_tuned_models.csv')

# %%
# blend top 3 models
top_3_blended = blend_models(top_3_models)
top_3_blended
# Out:
# <style type="text/css">
# #T_ff3f8_row5_col0, #T_ff3f8_row5_col1, #T_ff3f8_row5_col2, #T_ff3f8_row5_col3, #T_ff3f8_row5_col4, #T_ff3f8_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ff3f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff3f8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ff3f8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ff3f8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ff3f8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ff3f8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ff3f8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff3f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff3f8_row0_col0" class="data row0 col0" >0.2222</td>
#       <td id="T_ff3f8_row0_col1" class="data row0 col1" >0.1293</td>
#       <td id="T_ff3f8_row0_col2" class="data row0 col2" >0.3596</td>
#       <td id="T_ff3f8_row0_col3" class="data row0 col3" >0.9108</td>
#       <td id="T_ff3f8_row0_col4" class="data row0 col4" >0.1237</td>
#       <td id="T_ff3f8_row0_col5" class="data row0 col5" >0.2358</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff3f8_row1_col0" class="data row1 col0" >0.3045</td>
#       <td id="T_ff3f8_row1_col1" class="data row1 col1" >0.2681</td>
#       <td id="T_ff3f8_row1_col2" class="data row1 col2" >0.5178</td>
#       <td id="T_ff3f8_row1_col3" class="data row1 col3" >0.9011</td>
#       <td id="T_ff3f8_row1_col4" class="data row1 col4" >0.1428</td>
#       <td id="T_ff3f8_row1_col5" class="data row1 col5" >0.2164</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff3f8_row2_col0" class="data row2 col0" >0.2402</td>
#       <td id="T_ff3f8_row2_col1" class="data row2 col1" >0.1271</td>
#       <td id="T_ff3f8_row2_col2" class="data row2 col2" >0.3565</td>
#       <td id="T_ff3f8_row2_col3" class="data row2 col3" >0.9460</td>
#       <td id="T_ff3f8_row2_col4" class="data row2 col4" >0.1189</td>
#       <td id="T_ff3f8_row2_col5" class="data row2 col5" >0.1745</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff3f8_row3_col0" class="data row3 col0" >0.2337</td>
#       <td id="T_ff3f8_row3_col1" class="data row3 col1" >0.1292</td>
#       <td id="T_ff3f8_row3_col2" class="data row3 col2" >0.3594</td>
#       <td id="T_ff3f8_row3_col3" class="data row3 col3" >0.9489</td>
#       <td id="T_ff3f8_row3_col4" class="data row3 col4" >0.1163</td>
#       <td id="T_ff3f8_row3_col5" class="data row3 col5" >0.1953</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff3f8_row4_col0" class="data row4 col0" >0.2216</td>
#       <td id="T_ff3f8_row4_col1" class="data row4 col1" >0.1644</td>
#       <td id="T_ff3f8_row4_col2" class="data row4 col2" >0.4054</td>
#       <td id="T_ff3f8_row4_col3" class="data row4 col3" >0.9422</td>
#       <td id="T_ff3f8_row4_col4" class="data row4 col4" >0.1122</td>
#       <td id="T_ff3f8_row4_col5" class="data row4 col5" >0.1822</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ff3f8_row5_col0" class="data row5 col0" >0.2444</td>
#       <td id="T_ff3f8_row5_col1" class="data row5 col1" >0.1636</td>
#       <td id="T_ff3f8_row5_col2" class="data row5 col2" >0.3997</td>
#       <td id="T_ff3f8_row5_col3" class="data row5 col3" >0.9298</td>
#       <td id="T_ff3f8_row5_col4" class="data row5 col4" >0.1227</td>
#       <td id="T_ff3f8_row5_col5" class="data row5 col5" >0.2009</td>
#     </tr>
#     <tr>
#       <th id="T_ff3f8_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_ff3f8_row6_col0" class="data row6 col0" >0.0308</td>
#       <td id="T_ff3f8_row6_col1" class="data row6 col1" >0.0541</td>
#       <td id="T_ff3f8_row6_col2" class="data row6 col2" >0.0618</td>
#       <td id="T_ff3f8_row6_col3" class="data row6 col3" >0.0198</td>
#       <td id="T_ff3f8_row6_col4" class="data row6 col4" >0.0107</td>
#       <td id="T_ff3f8_row6_col5" class="data row6 col5" >0.0225</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# VotingRegressor(estimators=[('Huber Regressor', HuberRegressor()),
#                             ('Orthogonal Matching Pursuit',
#                              OrthogonalMatchingPursuit()),
#                             ('Ridge Regression',
#                              Ridge(alpha=0.54, random_state=123))],
#                 n_jobs=-1)

# %%
# stack models
top_3_stacked = stack_models(top_3_models)
top_3_stacked
# Out:
# <style type="text/css">
# #T_7283c_row5_col0, #T_7283c_row5_col1, #T_7283c_row5_col2, #T_7283c_row5_col3, #T_7283c_row5_col4, #T_7283c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7283c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7283c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7283c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7283c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7283c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7283c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7283c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7283c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7283c_row0_col0" class="data row0 col0" >0.2547</td>
#       <td id="T_7283c_row0_col1" class="data row0 col1" >0.1645</td>
#       <td id="T_7283c_row0_col2" class="data row0 col2" >0.4056</td>
#       <td id="T_7283c_row0_col3" class="data row0 col3" >0.8866</td>
#       <td id="T_7283c_row0_col4" class="data row0 col4" >0.1322</td>
#       <td id="T_7283c_row0_col5" class="data row0 col5" >0.2809</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7283c_row1_col0" class="data row1 col0" >0.3098</td>
#       <td id="T_7283c_row1_col1" class="data row1 col1" >0.2613</td>
#       <td id="T_7283c_row1_col2" class="data row1 col2" >0.5112</td>
#       <td id="T_7283c_row1_col3" class="data row1 col3" >0.9036</td>
#       <td id="T_7283c_row1_col4" class="data row1 col4" >0.1428</td>
#       <td id="T_7283c_row1_col5" class="data row1 col5" >0.2373</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7283c_row2_col0" class="data row2 col0" >0.2659</td>
#       <td id="T_7283c_row2_col1" class="data row2 col1" >0.1456</td>
#       <td id="T_7283c_row2_col2" class="data row2 col2" >0.3815</td>
#       <td id="T_7283c_row2_col3" class="data row2 col3" >0.9381</td>
#       <td id="T_7283c_row2_col4" class="data row2 col4" >0.1315</td>
#       <td id="T_7283c_row2_col5" class="data row2 col5" >0.1998</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7283c_row3_col0" class="data row3 col0" >0.2393</td>
#       <td id="T_7283c_row3_col1" class="data row3 col1" >0.1254</td>
#       <td id="T_7283c_row3_col2" class="data row3 col2" >0.3541</td>
#       <td id="T_7283c_row3_col3" class="data row3 col3" >0.9504</td>
#       <td id="T_7283c_row3_col4" class="data row3 col4" >0.1184</td>
#       <td id="T_7283c_row3_col5" class="data row3 col5" >0.1959</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7283c_row4_col0" class="data row4 col0" >0.2275</td>
#       <td id="T_7283c_row4_col1" class="data row4 col1" >0.1702</td>
#       <td id="T_7283c_row4_col2" class="data row4 col2" >0.4125</td>
#       <td id="T_7283c_row4_col3" class="data row4 col3" >0.9401</td>
#       <td id="T_7283c_row4_col4" class="data row4 col4" >0.1148</td>
#       <td id="T_7283c_row4_col5" class="data row4 col5" >0.1868</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_7283c_row5_col0" class="data row5 col0" >0.2594</td>
#       <td id="T_7283c_row5_col1" class="data row5 col1" >0.1734</td>
#       <td id="T_7283c_row5_col2" class="data row5 col2" >0.4130</td>
#       <td id="T_7283c_row5_col3" class="data row5 col3" >0.9238</td>
#       <td id="T_7283c_row5_col4" class="data row5 col4" >0.1280</td>
#       <td id="T_7283c_row5_col5" class="data row5 col5" >0.2201</td>
#     </tr>
#     <tr>
#       <th id="T_7283c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_7283c_row6_col0" class="data row6 col0" >0.0284</td>
#       <td id="T_7283c_row6_col1" class="data row6 col1" >0.0467</td>
#       <td id="T_7283c_row6_col2" class="data row6 col2" >0.0532</td>
#       <td id="T_7283c_row6_col3" class="data row6 col3" >0.0244</td>
#       <td id="T_7283c_row6_col4" class="data row6 col4" >0.0102</td>
#       <td id="T_7283c_row6_col5" class="data row6 col5" >0.0349</td>
#     </tr>
#   </tbody>
# </table>
# StackingRegressor(cv=5,
#                   estimators=[('Huber Regressor', HuberRegressor()),
#                               ('Orthogonal Matching Pursuit',
#                                OrthogonalMatchingPursuit()),
#                               ('Ridge Regression',
#                                Ridge(alpha=0.54, random_state=123))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1,
#                   passthrough=True)

# %%
# get leaderboard
lb = get_leaderboard()
lb
# Out:
#                             Model Name  \
# Index
# 0                    Linear Regression
# 1                     Lasso Regression
# 2                     Ridge Regression
# 3                          Elastic Net
# 4         Lasso Least Angle Regression
# 5          Orthogonal Matching Pursuit
# 6                       Bayesian Ridge
# 7         Passive Aggressive Regressor
# 8                      Huber Regressor
# 9                K Neighbors Regressor
# 10             Decision Tree Regressor
# 11             Random Forest Regressor
# 12               Extra Trees Regressor
# 13                  AdaBoost Regressor
# 14         Gradient Boosting Regressor
# 15     Light Gradient Boosting Machine
# 16                     Dummy Regressor
# 17                     Huber Regressor
# 18                     Huber Regressor
# 19         Orthogonal Matching Pursuit
# 20         Orthogonal Matching Pursuit
# 21                    Ridge Regression
# 22                    Ridge Regression
# 23                   Linear Regression
# 24                   Linear Regression
# 25                      Bayesian Ridge
# 26                      Bayesian Ridge
# 27                     Huber Regressor
# 28         Orthogonal Matching Pursuit
# 29                    Ridge Regression
# 30                   Linear Regression
# 31                      Bayesian Ridge
# 32                    Voting Regressor
# 33                  Stacking Regressor
#
#                                                    Model     MAE     MSE  \
# Index
# 0      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 1      (TransformerWrapper(include=['Year', 'Sand_1',...  0.6614  0.9859
# 2      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1736
# 3      (TransformerWrapper(include=['Year', 'Sand_1',...  0.4647  0.4926
# 4      (TransformerWrapper(include=['Year', 'Sand_1',...  0.6614  0.9860
# 5      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 6      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1744
# 7      (TransformerWrapper(include=['Year', 'Sand_1',...  0.3875  0.3242
# 8      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 9      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2791  0.2075
# 10     (TransformerWrapper(include=['Year', 'Sand_1',...  0.3617  0.3531
# 11     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2809  0.2219
# 12     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2656  0.1955
# 13     (TransformerWrapper(include=['Year', 'Sand_1',...  0.4508  0.3299
# 14     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2793  0.2075
# 15     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2782  0.2146
# 16     (TransformerWrapper(include=['Year', 'Sand_1',...  1.0424  2.4082
# 17     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2400  0.1620
# 18     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 19     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2523  0.1727
# 20     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 21     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1734
# 22     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1736
# 23     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 24     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 25     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1742
# 26     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1744
# 27     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 28     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 29     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1734
# 30     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 31     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1742
# 32     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2444  0.1636
# 33     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2594  0.1734
#
#          RMSE      R2   RMSLE    MAPE
# Index
# 0      0.4125  0.9245  0.1255  0.2106
# 1      0.9832  0.5902  0.2884  0.7978
# 2      0.4131  0.9242  0.1255  0.2104
# 3      0.6900  0.7973  0.2102  0.5564
# 4      0.9832  0.5902  0.2884  0.7978
# 5      0.4026  0.9288  0.1256  0.2156
# 6      0.4140  0.9236  0.1256  0.2104
# 7      0.5595  0.8619  0.1898  0.3946
# 8      0.3984  0.9300  0.1222  0.1946
# 9      0.4510  0.9083  0.1350  0.2319
# 10     0.5886  0.8367  0.1759  0.2796
# 11     0.4653  0.8976  0.1350  0.2241
# 12     0.4373  0.9140  0.1299  0.2176
# 13     0.5709  0.8485  0.2325  0.7066
# 14     0.4517  0.9059  0.1327  0.2318
# 15     0.4560  0.9003  0.1342  0.2193
# 16     1.5440 -0.0187  0.4547  1.2679
# 17     0.3982  0.9299  0.1220  0.1939
# 18     0.3984  0.9300  0.1222  0.1946
# 19     0.4119  0.9246  0.1254  0.2107
# 20     0.4026  0.9288  0.1256  0.2156
# 21     0.4128  0.9243  0.1255  0.2105
# 22     0.4131  0.9242  0.1255  0.2104
# 23     0.4125  0.9245  0.1255  0.2106
# 24     0.4125  0.9245  0.1255  0.2106
# 25     0.4138  0.9237  0.1255  0.2104
# 26     0.4140  0.9236  0.1256  0.2104
# 27     0.3984  0.9300  0.1222  0.1946
# 28     0.4026  0.9288  0.1256  0.2156
# 29     0.4128  0.9243  0.1255  0.2105
# 30     0.4125  0.9245  0.1255  0.2106
# 31     0.4138  0.9237  0.1255  0.2104
# 32     0.3997  0.9298  0.1227  0.2009
# 33     0.4130  0.9238  0.1280  0.2201

# %%
lb.sort_values(by='MAE', ascending=True)
# Out:
#                             Model Name  \
# Index
# 17                     Huber Regressor
# 18                     Huber Regressor
# 8                      Huber Regressor
# 27                     Huber Regressor
# 32                    Voting Regressor
# 20         Orthogonal Matching Pursuit
# 5          Orthogonal Matching Pursuit
# 28         Orthogonal Matching Pursuit
# 19         Orthogonal Matching Pursuit
# 2                     Ridge Regression
# 29                    Ridge Regression
# 21                    Ridge Regression
# 22                    Ridge Regression
# 0                    Linear Regression
# 24                   Linear Regression
# 25                      Bayesian Ridge
# 6                       Bayesian Ridge
# 30                   Linear Regression
# 31                      Bayesian Ridge
# 23                   Linear Regression
# 26                      Bayesian Ridge
# 33                  Stacking Regressor
# 12               Extra Trees Regressor
# 15     Light Gradient Boosting Machine
# 9                K Neighbors Regressor
# 14         Gradient Boosting Regressor
# 11             Random Forest Regressor
# 10             Decision Tree Regressor
# 7         Passive Aggressive Regressor
# 13                  AdaBoost Regressor
# 3                          Elastic Net
# 4         Lasso Least Angle Regression
# 1                     Lasso Regression
# 16                     Dummy Regressor
#
#                                                    Model     MAE     MSE  \
# Index
# 17     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2400  0.1620
# 18     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 8      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 27     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2413  0.1624
# 32     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2444  0.1636
# 20     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 5      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 28     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2513  0.1664
# 19     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2523  0.1727
# 2      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1736
# 29     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1734
# 21     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1734
# 22     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2526  0.1736
# 0      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 24     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 25     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1742
# 6      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1744
# 30     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 31     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1742
# 23     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1732
# 26     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2527  0.1744
# 33     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2594  0.1734
# 12     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2656  0.1955
# 15     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2782  0.2146
# 9      (TransformerWrapper(include=['Year', 'Sand_1',...  0.2791  0.2075
# 14     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2793  0.2075
# 11     (TransformerWrapper(include=['Year', 'Sand_1',...  0.2809  0.2219
# 10     (TransformerWrapper(include=['Year', 'Sand_1',...  0.3617  0.3531
# 7      (TransformerWrapper(include=['Year', 'Sand_1',...  0.3875  0.3242
# 13     (TransformerWrapper(include=['Year', 'Sand_1',...  0.4508  0.3299
# 3      (TransformerWrapper(include=['Year', 'Sand_1',...  0.4647  0.4926
# 4      (TransformerWrapper(include=['Year', 'Sand_1',...  0.6614  0.9860
# 1      (TransformerWrapper(include=['Year', 'Sand_1',...  0.6614  0.9859
# 16     (TransformerWrapper(include=['Year', 'Sand_1',...  1.0424  2.4082
#
#          RMSE      R2   RMSLE    MAPE
# Index
# 17     0.3982  0.9299  0.1220  0.1939
# 18     0.3984  0.9300  0.1222  0.1946
# 8      0.3984  0.9300  0.1222  0.1946
# 27     0.3984  0.9300  0.1222  0.1946
# 32     0.3997  0.9298  0.1227  0.2009
# 20     0.4026  0.9288  0.1256  0.2156
# 5      0.4026  0.9288  0.1256  0.2156
# 28     0.4026  0.9288  0.1256  0.2156
# 19     0.4119  0.9246  0.1254  0.2107
# 2      0.4131  0.9242  0.1255  0.2104
# 29     0.4128  0.9243  0.1255  0.2105
# 21     0.4128  0.9243  0.1255  0.2105
# 22     0.4131  0.9242  0.1255  0.2104
# 0      0.4125  0.9245  0.1255  0.2106
# 24     0.4125  0.9245  0.1255  0.2106
# 25     0.4138  0.9237  0.1255  0.2104
# 6      0.4140  0.9236  0.1256  0.2104
# 30     0.4125  0.9245  0.1255  0.2106
# 31     0.4138  0.9237  0.1255  0.2104
# 23     0.4125  0.9245  0.1255  0.2106
# 26     0.4140  0.9236  0.1256  0.2104
# 33     0.4130  0.9238  0.1280  0.2201
# 12     0.4373  0.9140  0.1299  0.2176
# 15     0.4560  0.9003  0.1342  0.2193
# 9      0.4510  0.9083  0.1350  0.2319
# 14     0.4517  0.9059  0.1327  0.2318
# 11     0.4653  0.8976  0.1350  0.2241
# 10     0.5886  0.8367  0.1759  0.2796
# 7      0.5595  0.8619  0.1898  0.3946
# 13     0.5709  0.8485  0.2325  0.7066
# 3      0.6900  0.7973  0.2102  0.5564
# 4      0.9832  0.5902  0.2884  0.7978
# 1      0.9832  0.5902  0.2884  0.7978
# 16     1.5440 -0.0187  0.4547  1.2679

# %%
# select the best model based on MAE
best_model = lb.sort_values(by='MAE', ascending=True)['Model'].iloc[0]

# %%
best_model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Year', 'Sand_1', 'Sand_2',
#                                              'Sand_3', 'Sand_4', 'Sand_5',
#                                              'Sand_6', 'Sand_7', 'Clay_1',
#                                              'Clay_2', 'Clay_3', 'Clay_4',
#                                              'Clay_5', 'Clay_6', 'Clay_7',
#                                              'OC_1', 'OC_2', 'OC_3', 'OC_4',
#                                              'OC_5', 'OC_6', 'OC_7', 'PAW_1',
#                                              'PAW_2', 'PAW_3', 'PAW_4', 'PAW_5',
#                                              'PAW_6', 'PAW_7',
#                                              'Sow_Maize_month_int', ...],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('normalize', TransformerWrapper(transformer=RobustScaler())),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ['trained_model', HuberRegressor(alpha=0.01, epsilon=1.1)]])

# %%
# predict on test set
holdout_pred = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a3ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a3ac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3a3ac_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3a3ac_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3a3ac_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3a3ac_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3a3ac_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3a3ac_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a3ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a3ac_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_3a3ac_row0_col1" class="data row0 col1" >0.1973</td>
#       <td id="T_3a3ac_row0_col2" class="data row0 col2" >0.1064</td>
#       <td id="T_3a3ac_row0_col3" class="data row0 col3" >0.3261</td>
#       <td id="T_3a3ac_row0_col4" class="data row0 col4" >0.9602</td>
#       <td id="T_3a3ac_row0_col5" class="data row0 col5" >0.0989</td>
#       <td id="T_3a3ac_row0_col6" class="data row0 col6" >0.1354</td>
#     </tr>
#   </tbody>
# </table>

# %%
# predict on test set
holdout_pred_stacked = predict_model(top_3_stacked)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35399">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35399_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35399_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_35399_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_35399_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_35399_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_35399_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_35399_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35399_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35399_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_35399_row0_col1" class="data row0 col1" >0.2130</td>
#       <td id="T_35399_row0_col2" class="data row0 col2" >0.1005</td>
#       <td id="T_35399_row0_col3" class="data row0 col3" >0.3170</td>
#       <td id="T_35399_row0_col4" class="data row0 col4" >0.9624</td>
#       <td id="T_35399_row0_col5" class="data row0 col5" >0.1156</td>
#       <td id="T_35399_row0_col6" class="data row0 col6" >0.1702</td>
#     </tr>
#   </tbody>
# </table>

# %%
# predict on test set
holdout_pred_blended = predict_model(top_3_blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1751f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1751f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1751f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1751f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1751f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1751f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1751f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1751f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1751f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1751f_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_1751f_row0_col1" class="data row0 col1" >0.1987</td>
#       <td id="T_1751f_row0_col2" class="data row0 col2" >0.1032</td>
#       <td id="T_1751f_row0_col3" class="data row0 col3" >0.3213</td>
#       <td id="T_1751f_row0_col4" class="data row0 col4" >0.9614</td>
#       <td id="T_1751f_row0_col5" class="data row0 col5" >0.0996</td>
#       <td id="T_1751f_row0_col6" class="data row0 col6" >0.1401</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Year', 'Sand_1', 'Sand_2',
#                                              'Sand_3', 'Sand_4', 'Sand_5',
#                                              'Sand_6', 'Sand_7', 'Clay_1',
#                                              'Clay_2', 'Clay_3', 'Clay_4',
#                                              'Clay_5', 'Clay_6', 'Clay_7',
#                                              'OC_1', 'OC_2', 'OC_3', 'OC_4',
#                                              'OC_5', 'OC_6', 'OC_7', 'PAW_1',
#                                              'PAW_2', 'PAW_3', 'PAW_4', 'PAW_5',
#                                              'PAW_6', 'PAW_7',
#                                              'Sow_Maize_month_int', ...],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('normalize', TransformerWrapper(transformer=RobustScaler())),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ['trained_model', HuberRegressor(alpha=0.01, epsilon=1.1)]])
